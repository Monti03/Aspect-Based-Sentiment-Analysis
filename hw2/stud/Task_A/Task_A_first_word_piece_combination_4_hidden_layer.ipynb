# %%
# !pip install torchtext --upgrade
# !pip install transformers
# !pip install pytorch_lightning
# Out:
# Requirement already up-to-date: torchtext in /usr/local/lib/python3.7/dist-packages (0.9.1)
# Requirement already satisfied, skipping upgrade: requests in /usr/local/lib/python3.7/dist-packages (from torchtext) (2.23.0)
# Requirement already satisfied, skipping upgrade: numpy in /usr/local/lib/python3.7/dist-packages (from torchtext) (1.19.5)
# Requirement already satisfied, skipping upgrade: torch==1.8.1 in /usr/local/lib/python3.7/dist-packages (from torchtext) (1.8.1+cu101)
# Requirement already satisfied, skipping upgrade: tqdm in /usr/local/lib/python3.7/dist-packages (from torchtext) (4.41.1)
# Requirement already satisfied, skipping upgrade: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (2020.12.5)
# Requirement already satisfied, skipping upgrade: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (3.0.4)
# Requirement already satisfied, skipping upgrade: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (2.10)
# Requirement already satisfied, skipping upgrade: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->torchtext) (1.24.3)
# Requirement already satisfied, skipping upgrade: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch==1.8.1->torchtext) (3.7.4.3)
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/d5/43/cfe4ee779bbd6a678ac6a97c5a5cdeb03c35f9eaebbb9720b036680f9a2d/transformers-4.6.1-py3-none-any.whl (2.2MB)
#      |████████████████████████████████| 2.3MB 7.3MB/s
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from transformers) (4.0.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.7/dist-packages (from transformers) (4.41.1)
# Collecting huggingface-hub==0.0.8
#   Downloading https://files.pythonhosted.org/packages/a1/88/7b1e45720ecf59c6c6737ff332f41c955963090a18e72acbcbeac6b25e86/huggingface_hub-0.0.8-py3-none-any.whl
# Collecting tokenizers<0.11,>=0.10.1
#   Downloading https://files.pythonhosted.org/packages/d4/e2/df3543e8ffdab68f5acc73f613de9c2b155ac47f162e725dcac87c521c11/tokenizers-0.10.3-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (3.3MB)
#      |████████████████████████████████| 3.3MB 47.9MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from transformers) (20.9)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from transformers) (1.19.5)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/75/ee/67241dc87f266093c533a2d4d3d69438e57d7a90abb216fa076e7d475d4a/sacremoses-0.0.45-py3-none-any.whl (895kB)
#      |████████████████████████████████| 901kB 44.6MB/s
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from transformers) (3.0.12)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->transformers) (3.4.1)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->transformers) (2.4.7)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.0.1)
# Requirement already satisfied: click in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from sacremoses->transformers) (1.15.0)
# Installing collected packages: huggingface-hub, tokenizers, sacremoses, transformers
# Successfully installed huggingface-hub-0.0.8 sacremoses-0.0.45 tokenizers-0.10.3 transformers-4.6.1
# Collecting pytorch_lightning
#   Downloading https://files.pythonhosted.org/packages/b6/6a/20d0bf3b967ab62333efea36fe922aaa252d1762555b4a7afb2be5bbdcbf/pytorch_lightning-1.3.5-py3-none-any.whl (808kB)
#      |████████████████████████████████| 808kB 8.5MB/s
# Collecting future>=0.17.1
#   Downloading https://files.pythonhosted.org/packages/45/0b/38b06fd9b92dc2b68d58b75f900e97884c45bedd2ff83203d933cf5851c9/future-0.18.2.tar.gz (829kB)
#      |████████████████████████████████| 829kB 29.6MB/s
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (4.41.1)
# Collecting tensorboard!=2.5.0,>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/64/21/eebd23060763fedeefb78bc2b286e00fa1d8abda6f70efa2ee08c28af0d4/tensorboard-2.4.1-py3-none-any.whl (10.6MB)
#      |████████████████████████████████| 10.6MB 37.5MB/s
# Collecting pyDeprecate==0.3.0
#   Downloading https://files.pythonhosted.org/packages/14/52/aa227a0884df71ed1957649085adf2b8bc2a1816d037c2f18b3078854516/pyDeprecate-0.3.0-py3-none-any.whl
# Requirement already satisfied: torch>=1.4 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (1.8.1+cu101)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (1.19.5)
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from pytorch_lightning) (20.9)
# Collecting torchmetrics>=0.2.0
#   Downloading https://files.pythonhosted.org/packages/3b/e8/513cd9d0b1c83dc14cd8f788d05cd6a34758d4fd7e4f9e5ecd5d7d599c95/torchmetrics-0.3.2-py3-none-any.whl (274kB)
#      |████████████████████████████████| 276kB 45.3MB/s
# Collecting PyYAML<=5.4.1,>=5.1
#   Downloading https://files.pythonhosted.org/packages/7a/a5/393c087efdc78091afa2af9f1378762f9821c9c1d7a22c5753fb5ac5f97a/PyYAML-5.4.1-cp37-cp37m-manylinux1_x86_64.whl (636kB)
#      |████████████████████████████████| 645kB 45.1MB/s
# Collecting fsspec[http]!=2021.06.0,>=2021.05.0
#   Downloading https://files.pythonhosted.org/packages/bc/52/816d1a3a599176057bf29dfacb1f8fadb61d35fbd96cb1bab4aaa7df83c0/fsspec-2021.5.0-py3-none-any.whl (111kB)
#      |████████████████████████████████| 112kB 57.8MB/s
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (2.23.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (3.3.4)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (1.34.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (0.12.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (57.0.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (3.12.4)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (0.36.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (1.0.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (1.30.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (1.15.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (0.4.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (1.8.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.4->pytorch_lightning) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->pytorch_lightning) (2.4.7)
# Collecting aiohttp; extra == "http"
#   Downloading https://files.pythonhosted.org/packages/88/c0/5890b4c8b04a79b7360e8fe4490feb0bb3ab179743f199f0e6220cebd568/aiohttp-3.7.4.post0-cp37-cp37m-manylinux2014_x86_64.whl (1.3MB)
#      |████████████████████████████████| 1.3MB 38.7MB/s
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (2020.12.5)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (4.0.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (1.3.0)
# Collecting multidict<7.0,>=4.5
#   Downloading https://files.pythonhosted.org/packages/7c/a6/4123b8165acbe773d1a8dc8e3f0d1edea16d29f7de018eda769abb56bd30/multidict-5.1.0-cp37-cp37m-manylinux2014_x86_64.whl (142kB)
#      |████████████████████████████████| 143kB 56.8MB/s
# Collecting yarl<2.0,>=1.0
#   Downloading https://files.pythonhosted.org/packages/f1/62/046834c5fc998c88ab2ef722f5d42122230a632212c8afa76418324f53ff/yarl-1.6.3-cp37-cp37m-manylinux2014_x86_64.whl (294kB)
#      |████████████████████████████████| 296kB 49.4MB/s
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (21.2.0)
# Collecting async-timeout<4.0,>=3.0
#   Downloading https://files.pythonhosted.org/packages/e1/1e/5a4441be21b0726c4464f3f23c8b19628372f606755a9d2e46c187e65ec4/async_timeout-3.0.1-py3-none-any.whl
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (3.4.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard!=2.5.0,>=2.2.0->pytorch_lightning) (3.1.0)
# Building wheels for collected packages: future
#   Building wheel for future (setup.py) ... done
#   Created wheel for future: filename=future-0.18.2-cp37-none-any.whl size=491070 sha256=3d0777923ff8878c7e02e92552ba57201a7fc9011fcb438f2feaeb33c69aa052
#   Stored in directory: /root/.cache/pip/wheels/8b/99/a0/81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e
# Successfully built future
# ERROR: tensorflow 2.5.0 has requirement tensorboard~=2.5, but you'll have tensorboard 2.4.1 which is incompatible.
# Installing collected packages: future, tensorboard, pyDeprecate, torchmetrics, PyYAML, multidict, yarl, async-timeout, aiohttp, fsspec, pytorch-lightning
#   Found existing installation: future 0.16.0
#     Uninstalling future-0.16.0:
#       Successfully uninstalled future-0.16.0
#   Found existing installation: tensorboard 2.5.0
#     Uninstalling tensorboard-2.5.0:
#       Successfully uninstalled tensorboard-2.5.0
#   Found existing installation: PyYAML 3.13
#     Uninstalling PyYAML-3.13:
#       Successfully uninstalled PyYAML-3.13
# Successfully installed PyYAML-5.4.1 aiohttp-3.7.4.post0 async-timeout-3.0.1 fsspec-2021.5.0 future-0.18.2 multidict-5.1.0 pyDeprecate-0.3.0 pytorch-lightning-1.3.5 tensorboard-2.4.1 torchmetrics-0.3.2 yarl-1.6.3

# %% [markdown]
# And download data that we need.

# %%
# !git clone https://github.com/SapienzaNLP/nlp2021-hw2
# Out:
# Cloning into 'nlp2021-hw2'...
# remote: Enumerating objects: 32, done.
# remote: Counting objects: 100% (32/32), done.
# remote: Compressing objects: 100% (27/27), done.
# remote: Total 32 (delta 10), reused 18 (delta 3), pack-reused 0
# Unpacking objects: 100% (32/32), done.

# %%
import os

data_folder = os.sep.join(["nlp2021-hw2", "data"])
training_file = [os.sep.join([data_folder, "restaurants_train.json"]), os.sep.join([data_folder, "laptops_train.json"])]
dev_file = [os.sep.join([data_folder, "restaurants_dev.json"]),os.sep.join([data_folder, "laptops_dev.json"])]

# %%
# here go all the imports
import torch
from torch import nn
from torch.utils.data import Dataset
from torchtext import data
from torchtext.vocab import Vectors
from transformers import BertTokenizer, BertModel


from pprint import pprint
from tqdm import tqdm
from torchtext.vocab import Vocab
from collections import Counter
import random
import numpy as np

from typing import *

import json

import pytorch_lightning as pl
from torch.utils.data import DataLoader
import torch.optim as optim

from pytorch_lightning.callbacks.early_stopping import EarlyStopping
from pytorch_lightning.callbacks.model_checkpoint import ModelCheckpoint

from sklearn.metrics import f1_score

# %% [markdown]
# Set up the seed and deterministic algorithms in order to have reproducible results

# %%
SEED = 96

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.backends.cudnn.deterministic = True

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# #### Load Data

# %%
class MyDataset(Dataset):

    def __init__(self, 
                 input_file:List,
                 tokenizer,  
                 test=False,
                 device="cpu"):
        """
        Args:
            input_file (list of strings or paths): each element is a path to a dataset to be loaded.
            tokeniser BertTokenizer: the tokernizer to be used 
            test Boolean: True if the dataset is used for testing pourposes
            device (string): device where to put tensors (cpu or cuda).
        """

        self.test = test
        self.input_file = input_file
        
        # load the jsonlines into a list of dictionaries
        with open(input_file[0]) as fin:
            data0 = json.load(fin)
        with open(input_file[1]) as fin:
            data1 = json.load(fin)
        
        self.data = data0 + data1

        self.tokenizer = tokenizer
        self.device = device
        self.encoded_data = None
        # initialize the data
        self.init_data()
    
    def get_indexes_to_merge(self, word_pieces:List, start_idx:int):

        # get the indeces and the number of word pieces that have to me merged
        word_pieces_to_merge = []
        
        # started is used in order to know if a term formed by more word pieces
        # is aleady started
        started = False
        
        # number of word pieces starting with ##
        tot_to_subtract = 0 
        
        
        for i, word_piece in enumerate(word_pieces):
            idx = start_idx + i

            # if the word piece starts with ##, this measn that is part of 
            # another token
            if (len(word_piece)>2 and word_piece[0:2] == "##"):
                # if the term has already seen a word piece with ## we append only
                if (started):
                    word_pieces_to_merge[-1].append(idx)
                
                # otherwise we have to add a new element to the list of 
                # word pieces that for a term
                else:
                    word_pieces_to_merge.append([idx-1, idx])
                started = True
                tot_to_subtract += 1
            else:
                started = False
        
        return word_pieces_to_merge, tot_to_subtract
                      
    # turn list of word pieces into string
    def word_pieces2string(self, word_pieces:List):
        s = ""
        for word_piece in word_pieces:
            if (len(word_piece) > 2 and word_piece[:2] == "##"):
                s += word_piece[2:]
            else:
                s += " " + word_piece
        return s

    def init_data(self):
        self.encoded_data = list()
        
        for i in range(len(self.data)):

            text = self.data[i]["text"]
            last_idx = 0
            
            # sort the targets w.r.t. the starting index
            targets = sorted(self.data[i]["targets"], key=lambda x: x[0][0])
            
            # tokenized stars with [101] since 101 is the id relative to the 
            # CLS token for BertTokenizer
            tokenized, label_indexes = [101], []
            rebuild_phrase = ["[start]"]

            to_subtract = 0

            word_pieces_to_merge = []
            true_targets = []
            
            # if we are testing, than we split the data without knowing where the
            # aspect terms are (during train I prefer to split according to the
            # aspect terms since there is no a correct manner to split them
            # cause some chars (like dash) are threadet in different manner in
            # the different aspect terms)
            if (self.test):
                # intialize the true aspect terms
                for true_target in targets:
                    true_targets.append(true_target[1])
                
                # tokenize the data
                word_pieces = self.tokenizer.tokenize(text)

                # get the indices of the word pieces to merge (the ones that
                # for a single term)
                word_pieces_to_merge, tmp_to_subtract = self.get_indexes_to_merge(word_pieces, len(tokenized))

                # rebuild the phrase (by concatenating the word pieces of the 
                # same term) and than split over the spaces
                rebuild_phrase += self.word_pieces2string(word_pieces).split()

                # get the indices to feed in input to bert 
                tokenized = self.tokenizer.encode(word_pieces)

                assert tokenized.count(101) == 1 and tokenized.count(102) == 1  
                assert tokenized[0] == 101 and tokenized[-1] == 102
                ''' tokenized.remove(101)
                tokenized.remove(102)

                if (101 in tokenized):
                    tokenized.remove(101)
                if (102 in tokenized):
                    tokenized.remove(102)
                
                tokenized = [101] + tokenized + [102] '''

                # get the len of the phrase (where the word pieces of the same
                # term are merged)
                length = len(rebuild_phrase)

                self.encoded_data.append({
                    "inputs": torch.tensor(tokenized),
                    "outputs": None,
                    "rebuild_phrase": rebuild_phrase,
                    "word_pieces_to_merge": word_pieces_to_merge,
                    "lengths":length,
                    "true_targets": true_targets
                })
            else: 
                # in case of train/dev I split the text by knowing where the
                # aspect terms are

                for true_target in targets:
                    # get start and end idx of the aspect term
                    start_idx, end_idx = true_target[0][0], true_target[0][1]
                    

                    # get the word pieces of the text between the end of the last
                    # aspect term considered and the beginning of this aspect term
                    word_pieces_pre = self.tokenizer.tokenize(text[last_idx:start_idx])

                    # get the word pieces of the aspect term
                    word_pieces_target = self.tokenizer.tokenize(text[start_idx:end_idx])

                    # concatenate the word pieces
                    word_pieces = word_pieces_pre + word_pieces_target 
                    

                    # get the indices of the word pieces that form a single token
                    tmp_word_pieces_to_merge, tmp_to_subtract = self.get_indexes_to_merge(word_pieces, len(tokenized))
                    word_pieces_to_merge += tmp_word_pieces_to_merge
                    # counter of the number of elements with ##
                    # is used in order to check that:
                    # n_tokens + n_word_pieces_with_## = n_word_pieces
                    to_subtract += tmp_to_subtract

                    tokenized += self.tokenizer.encode(word_pieces)
                    
                    # remove the newly added 101 and 102 
                    tokenized.reverse()
                    tokenized.remove(101)
                    tokenized.remove(102)
                    tokenized.reverse()

                    # merge the word pieces that are referred to as single term
                    # word_pieces_pre (word pieces of the text between the end of the last
                    # aspect term considered and the beginning of this aspect term)
                    rebuild_phrase += self.word_pieces2string(word_pieces_pre).split()
                    start_label_idx = len(rebuild_phrase) 
                    
                    # do the same for the target
                    rebuild_target = self.word_pieces2string(word_pieces_target).split()
                    rebuild_phrase += rebuild_target


                    # save the indices of the aspect terms
                    label_indexes += list(range(start_label_idx, start_label_idx + len(rebuild_target)))

                    # save the true aspect terms
                    true_targets.append(true_target[1])
                    last_idx = end_idx


                if (len(text) > last_idx):
                    word_pieces = self.tokenizer.tokenize(text[last_idx:])
                    tmp_word_pieces_to_merge, tmp_to_subtract = self.get_indexes_to_merge(word_pieces, len(tokenized))
                    word_pieces_to_merge += tmp_word_pieces_to_merge
                    to_subtract+=tmp_to_subtract 

                    tokenized += self.tokenizer.encode(word_pieces)
                    rebuild_phrase += self.word_pieces2string(word_pieces).split()

                     # remove the newly added 101 and 102 
                    tokenized.reverse()
                    tokenized.remove(101)
                    tokenized.remove(102)
                    tokenized.reverse()

                    ''' tokenized.remove(101)
                    tokenized.remove(102) '''
                ''' if (101 in tokenized):
                    tokenized.remove(101)
                if (102 in tokenized):
                    tokenized.remove(102) '''

                #tokenized = [101] + tokenized
                # add the ID that reprensets the SEP token
                tokenized.append(102)
                rebuild_phrase.append("[end]")

                assert tokenized.count(101) == 1 and tokenized.count(102) == 1  
                assert tokenized[0] == 101 and tokenized[-1] == 102

                # get the number of tokens (not word pieces) in the sentece
                length = len(rebuild_phrase)

                # check that the number of word pieces to merge is equal to the
                # number counted precedently 
                compute_diff = 0
                for wp in word_pieces_to_merge:
                    compute_diff += len(wp)-1

                assert compute_diff == to_subtract


                # assert that n_tokens + n_word_pieces_with_## = n_word_pieces
                labels = [0.0]*len(rebuild_phrase) 
                for index in label_indexes:
                    labels[index] = 1.0

                assert len(tokenized) ==  len(rebuild_phrase) + to_subtract

                self.encoded_data.append({
                    "inputs": torch.tensor(tokenized),
                    "outputs": torch.tensor(labels),
                    "rebuild_phrase": rebuild_phrase,
                    "word_pieces_to_merge": word_pieces_to_merge,
                    "lengths":length,
                    "true_targets": true_targets
                })
                      

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.encoded_data[idx]
    
    def get_raw_element(self, idx):
        return self.data[idx]

# %% [markdown]
# #### Define the torch Model

# %%
class MyModel(nn.Module):
    
    def __init__(self, hparams):
        super(MyModel, self).__init__()
        # load the pretrained bert large cased model
        self.bert = BertModel.from_pretrained('bert-large-cased', output_hidden_states=True)

        # define dropout and the FC
        self.dropout = nn.Dropout(hparams.dropout)
        
        # 4*1024 since 1024 is the size of an hidden layer, 4 cause we 
        # concatenate the last 4 hidden layers
        
        # 1 since I am doing binary classification
        self.lin1 = torch.nn.Linear(4*1024, 1)


    """
        x: dict with 
          input_ids: the padded sequence of ids of word pieces
          attention_mask
        word_pieces: list containing the indices of the word pieces that we have
                     to merge in order to get the result for a token
    """

    def forward(self, x, word_pieces, lenghts):
        bert_out = self.bert(input_ids=x["input_ids"], attention_mask=x["attention_mask"]).hidden_states
        x=x["input_ids"]

        # initialize the lists that will contain the embeddings of the tokens
        # (not word pieces)
        last_embs = []
        last_but_one_embs = []
        last_but_two_embs = []
        last_but_three_embs = []
        
        # for each phrase, compute the list of embs of the terms inside it 
        # by considering for each token only the first word piece
        for i in range(x.shape[0]):
            last_list_of_embs = []
            last_but_one_list_of_embs = []
            last_but_two_list_of_embs = []
            last_but_three_list_of_embs = []
            
            last = 0
            
            # for each token formed by multiple word pieces take the first word piece
            # from the last 4 hidden layers
            for word_piece in word_pieces[i]:
                last_list_of_embs+=bert_out[-1][i][last:word_piece[0]]
                last_list_of_embs.append(bert_out[-1][i][word_piece[0]])
                
                last_but_one_list_of_embs+=bert_out[-2][i][last:word_piece[0]]
                last_but_one_list_of_embs.append(bert_out[-2][i][word_piece[0]])
                
                last_but_two_list_of_embs+=bert_out[-3][i][last:word_piece[0]]
                last_but_two_list_of_embs.append(bert_out[-3][i][word_piece[0]])
                
                last_but_three_list_of_embs+=bert_out[-4][i][last:word_piece[0]]
                last_but_three_list_of_embs.append(bert_out[-4][i][word_piece[0]])
                
                last = word_piece[-1]+1
            
            # take the tokens from the last term formed by multiple word pieces
            # and the end of the sentence
            if (last < bert_out[-1][i].shape[0]):
                last_list_of_embs+=bert_out[-1][i][last:lenghts[i]]
                last_but_one_list_of_embs+=bert_out[-2][i][last:lenghts[i]]
                last_but_two_list_of_embs+=bert_out[-3][i][last:lenghts[i]]
                last_but_three_list_of_embs+=bert_out[-4][i][last:lenghts[i]]


            #stack the embs of the terms of the sentence
            last_list_of_embs = torch.stack(last_list_of_embs)
            last_but_one_list_of_embs = torch.stack(last_but_one_list_of_embs)
            last_but_two_list_of_embs = torch.stack(last_but_two_list_of_embs)
            last_but_three_list_of_embs = torch.stack(last_but_three_list_of_embs)

            # add the stacked embs into these lists
            last_embs.append(last_list_of_embs)
            last_but_one_embs.append(last_but_one_list_of_embs)
            last_but_two_embs.append(last_but_two_list_of_embs)
            last_but_three_embs.append(last_but_three_list_of_embs)


        # pad the sequences with zeros
        last_padded_embs = torch.nn.utils.rnn.pad_sequence(last_embs, batch_first=True, padding_value=0)
        last_but_one_padded_embs = torch.nn.utils.rnn.pad_sequence(last_but_one_embs, batch_first=True, padding_value=0)
        last_but_two_padded_embs = torch.nn.utils.rnn.pad_sequence(last_but_two_embs, batch_first=True, padding_value=0)
        last_but_three_padded_embs = torch.nn.utils.rnn.pad_sequence(last_but_three_embs, batch_first=True, padding_value=0)

        # save memory
        last_embs = None
        last_but_one_embs = None
        last_but_two_embs = None
        last_but_three_embs = None

        # concatenate the results from the last 4 hidden layers of bert
        padded_embs = torch.cat((last_padded_embs, last_but_one_padded_embs, last_but_two_padded_embs, last_but_three_padded_embs), -1)

        # save memory
        last_padded_embs = None
        last_but_one_padded_embs = None
        last_but_two_padded_embs = None
        last_but_three_padded_embs = None

        padded_embs = self.dropout(padded_embs)

        out = self.lin1(padded_embs)
        
        return out

# %% [markdown]
# #### Pytorch Lightning Module (Train, Dev and Test code)

# %%
class MyLightningModule(pl.LightningModule):
    def __init__(self, hparams, *args, **kwargs):
        super(MyLightningModule, self).__init__(*args, **kwargs)
        """
          hparams contains the dropout value
        """
        self.save_hyperparameters(hparams)

        # initialize the binary cross entropy loss 
        self.loss_function = torch.nn.BCELoss()
        
        # initialize the model
        self.model = MyModel(self.hparams)

        self.tp = 0
        self.fp = 0
        self.fn = 0

    
    # This performs a forward pass of the model, as well as returning the predicted index.
    """
        x is a dictionary containing the inputs_ids and the attention mask: the parameters of bert
        lengths is a list containing the number of word pieces for each sentence (not the number of tokens)
    """
    def forward(self, x, word_pieces, lenghts):
        logits = self.model(x, word_pieces, lenghts)

        return logits

    # This runs the model in training mode mode, ie. activates dropout and gradient computation. It defines a single training step.
    def training_step(self, batch, batch_nb):

        inputs = batch['inputs'] # input_ids and attention mask
        labels = batch['outputs'] # correct binary labels
        lenghts = batch['lengths'] # number of tokens per sentence
        input_lengths = batch["input_lengths"] # number of word piece per sentence

        mask = batch['mask'] # mask used to ignore the output for the padding values
        word_pieces = batch["word_pieces"] # idxs of word pieces to merge

        # forward pass
        logits = self.forward(inputs, word_pieces, input_lengths)
        
        #remove the outputs for the padded values
        logits = logits.view(-1, logits.shape[-1]).squeeze()[mask]
        
        labels = labels.view(-1)

        # compute the loss:
        loss = self.loss_function(torch.sigmoid(logits), labels)

        self.log('train_loss', loss, prog_bar=True, on_epoch=True)

        # return the loss in order to update the weights
        return loss
    

    # This runs the model in eval mode, ie. sets dropout to 0 and deactivates grad. Needed when we are in inference mode.
    def validation_step(self, batch, batch_nb):
        inputs = batch['inputs']# input_ids and attention mask
        labels = batch['outputs']# correct binary labels
        lengths = batch['lengths']# number of tokens per sentence
        input_lengths = batch["input_lengths"]# number of word piece per sentence
        
        mask = batch['mask']# mask used to ignore the output for the padding values
        word_pieces = batch["word_pieces"]# idxs of word pieces to merge

        # forward pass
        logits = self.forward(inputs, word_pieces, input_lengths)
        
        #remove the outputs for the padded values
        logits = logits.view(-1, logits.shape[-1]).squeeze()[mask]
        
        
        labels = labels.view(-1)
        
        # apply sigmoid and round the predictions
        preds = torch.sigmoid(logits)
        rounded = torch.round(preds)
        
        # compute loss and f1 score
        sample_loss = self.loss_function(preds, labels)
        sample_f1 = f1_score(labels.detach().cpu(), rounded.detach().cpu(), average="macro")

        self.log('valid_loss', sample_loss, prog_bar=True,on_epoch=True)
        self.log('valid_f1', sample_f1, prog_bar=True, on_epoch=True)


    # This runs the model in eval mode, ie. sets dropout to 0 and deactivates grad. Needed when we are in inference mode.
    def test_step(self, batch, batch_nb):
        inputs = batch['inputs']# input_ids and attention mask
        labels = batch['outputs']# correct binary labels
        lengths = batch['lengths']# number of tokens per sentence
        input_lengths = batch["input_lengths"]# number of word piece per sentence
        
        mask = batch['mask']# mask used to ignore the output for the padding values
        word_pieces = batch["word_pieces"]# idxs of word pieces to merge

        true_targets = batch['true_targets'] # correct aspect terms
        splitted_texts = batch['splitted_texts'] # splitted text
        

        # forward pass
        logits = self.forward(inputs, word_pieces, input_lengths)
        
        # apply sigmoid and round the predicions
        preds = torch.sigmoid(logits)
        rounded = torch.round(preds)

        # for each sentence
        for i, row_ in enumerate(rounded):

            # avoid to consider the padding
            row = row_[:lengths[i]]

            # get the indices with 1
            indeces = (row.squeeze()==1).nonzero()

            computed_targets, last_index = [], -1
            if (lengths[i] == 1):
                if (row[0][0] == 1):
                    computed_targets = splitted_texts[i][0]                                        
            else:
                for index in indeces:
                    # if an index is not equal to the precedent considered + 1
                    # we create a new aspect term
                    if (index != last_index + 1 or last_index == -1):
                        computed_targets.append(splitted_texts[i][index])
                    
                    # otherwise we concatenate to the precedent one (by considering
                    # that for some special chars we have to not put the space)
                    elif computed_targets[-1][-1] in ["-","(",")","/"] or splitted_texts[i][index] in ["-","(",")","/"]: 
                        computed_targets[-1] += splitted_texts[i][index]
                    else:
                        computed_targets[-1] += " " + splitted_texts[i][index]

                    last_index = index 

            true_out = true_targets[i]
            
            print("preds:", computed_targets)
            print("true:", true_out)

            # update the values of TP, FP and FN
            self.tp += len(set(true_out) & set(computed_targets))
            self.fp += len(set(computed_targets) - set(true_out))
            self.fn += len(set(true_out) - set(computed_targets))

            print("tp:", self.tp, "fp:", self.fp, "fn:",self.fn)

        
        precision = self.tp / (self.tp + self.fp)
        recall = self.tp / (self.tp + self.fn)
            
        avg_f1 = 2* (precision*recall) / (precision + recall)
        print(avg_f1, precision, recall, self.tp, self.fp, self.fn)
        
        self.log('test_f1', avg_f1, prog_bar=True, on_epoch=True)
        self.log('test_recall', recall, prog_bar=True, on_epoch=True)
        self.log('test_precision', precision, prog_bar=True, on_epoch=True)

    def configure_optimizers(self):
        return optim.Adam(self.parameters(), lr=0.000_05)

# %%
"""
data is a list of dictionaries                
                {
                    "inputs": torch.tensor of the word piece ids of the sentence
                    "outputs": torch.tensor of the labels for each term,
                    "rebuild_phrase": the rebuilded phrase,
                    "word_pieces_to_merge": the indices of the word peices that for a single token,
                    "lengths": the number of terms in the sentence
                    "true_targets": the true aspect terms
                }
"""

def collate_fn(data):
    # get the indices of the word pieces
    X = [entry["inputs"] for entry in data]

    # get the number of word pieces for each sentence
    input_lengths = [entry["inputs"].shape[0] for entry in data]

    # get the number of tokens for each sentence
    lengths = [entry["lengths"] for entry in data]

    # pad the indices 
    X = torch.nn.utils.rnn.pad_sequence(X, batch_first=True, padding_value=0)# TODO vocabulary.stoi("<pad>")  #  shape (batch_size x max_seq_len)
    y = torch.hstack([entry["outputs"] for entry in data]) if data[0]["outputs"]!= None else None

    # prepare the mask in order to avoid to consider the padding values
    # after flattening the output of the model
    mask = [ True if i<len else False for len in lengths for i in range(max(lengths)) ]

    # get the word pieces indices that form a single term
    word_pieces = [entry["word_pieces_to_merge"] for entry in data]
    
    # get the true aspect term and the splitted text
    true_targets = [entry["true_targets"] for entry in data]
    splitted_texts = [entry["rebuild_phrase"] for entry in data]

    # build the attention mask with 1 everywhere but over the padding word pieces
    attention_masks = torch.tensor([[1]*i_len + [0]*(X.shape[1] - i_len) for i_len in input_lengths])

    # define the bert input
    input = {"input_ids": X, "attention_mask": attention_masks}

    return {"inputs":input, "outputs":y, "lengths":lengths, "mask":mask, "true_targets":true_targets, "splitted_texts": splitted_texts, "word_pieces": word_pieces, "input_lengths":input_lengths}

# %%
class MyLightningDataModule(pl.LightningDataModule):
    def __init__(self, training_file, dev_file, tokenizer, collate_fn, device="cpu"):
        super().__init__()
        self.training_file = training_file
        self.dev_file = dev_file
        self.tokenizer = tokenizer
        self.collate_fn = collate_fn
        self.device = device

    def setup(self, stage=None):
      # initialize the three datasets
      self.trainingset = MyDataset(self.training_file, device=self.device, tokenizer=self.tokenizer)
      self.devset = MyDataset(self.dev_file, device=self.device, tokenizer=self.tokenizer)

      # same file as the dev set, but in this case the tokenization is done
      # whitout knowing where the aspect term are      
      self.testset = MyDataset(self.dev_file, device=self.device, tokenizer=self.tokenizer, test=True)

          
    def train_dataloader(self):
      return DataLoader(self.trainingset, batch_size=32, collate_fn = self.collate_fn, shuffle=True)
    
    def val_dataloader(self):
        return DataLoader(self.devset, batch_size=32, collate_fn = self.collate_fn)
    
    def test_dataloader(self):
        return DataLoader(self.testset, batch_size=len(self.testset)//5, collate_fn = self.collate_fn)

# %% [markdown]
# #### Define Hyperparams and start Training

# %%
hparams = {
            "dropout": 0.5
           }

# %%
# setup early stopping and checkpoint callbacks
# in order to stop the train after patience epochs from the lowest loss
# and save the model with lower loss
early_stop_callback = EarlyStopping(
   monitor="valid_loss",
   min_delta=0.00,
   patience=3,
   verbose=False,
   mode="min"
)


checkpoint_callback = ModelCheckpoint(
    dirpath="checkpoints",
    filename="best_model",
    monitor = "valid_loss",
    mode = "min"
)

tokenizer = BertTokenizer.from_pretrained('bert-large-cased')

# initialize the datamodule and the trainer
data_module = MyLightningDataModule(training_file, dev_file, tokenizer, collate_fn, device=device)
trainer = pl.Trainer(val_check_interval=1.0, max_epochs=15, gpus=1 if device!=torch.device('cpu') else None, callbacks=[early_stop_callback, checkpoint_callback])
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=213450.0, style=ProgressStyle(descripti…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=29.0, style=ProgressStyle(description_w…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=435797.0, style=ProgressStyle(descripti…
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores

# %%
# initialize the model and start the training
model = MyLightningModule(hparams)
trainer.fit(model, datamodule=data_module)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=762.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=1338740706.0, style=ProgressStyle(descr…
# Some weights of the model checkpoint at bert-large-cased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#   | Name          | Type    | Params
# ------------------------------------------
# 0 | loss_function | BCELoss | 0
# 1 | model         | MyModel | 333 M
# ------------------------------------------
# 333 M     Trainable params
# 0         Non-trainable params
# 333 M     Total params
# 1,334.333 Total estimated model params size (MB)
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validation sanity check', layout=Layout…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Training', layout=Layout(flex='2'), max…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Validating', layout=Layout(flex='2'), m…

# %% [markdown]
# ### Model Evaluation

# %%
ls -la checkpoints/
# Out:
# total 3901412
# drwxr-xr-x 2 root root       4096 Jun  9 09:26 ./
# drwxr-xr-x 1 root root       4096 Jun  9 09:26 ../
# -rw-r--r-- 1 root root 3995029721 Jun  9 09:28 best_model.ckpt

# %%
chk_path = "checkpoints/best_model.ckpt"
model = MyLightningModule.load_from_checkpoint(chk_path)
# Out:
# Some weights of the model checkpoint at bert-large-cased were not used when initializing BertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias', 'cls.seq_relationship.weight', 'cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).

# %%
trainer.test(model, test_dataloaders=data_module.test_dataloader())
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# HBox(children=(FloatProgress(value=1.0, bar_style='info', description='Testing', layout=Layout(flex='2'), max=…
# preds: []
# true: []
# tp: 0 fp: 0 fn: 0
# preds: ['wines', 'the glass']
# true: ['wines by the glass']
# tp: 0 fp: 2 fn: 1
# preds: ['staff']
# true: ['staff']
# tp: 1 fp: 2 fn: 1
# preds: []
# true: []
# tp: 1 fp: 2 fn: 1
# preds: ['Appetizers', 'main dishes']
# true: ['Appetizers', 'main dishes']
# tp: 3 fp: 2 fn: 1
# preds: []
# true: ['view']
# tp: 3 fp: 2 fn: 2
# preds: ['reservation']
# true: ['reservation']
# tp: 4 fp: 2 fn: 2
# preds: ['half price sushi deal']
# true: ['half price sushi deal']
# tp: 5 fp: 2 fn: 2
# preds: []
# true: []
# tp: 5 fp: 2 fn: 2
# preds: []
# true: []
# tp: 5 fp: 2 fn: 2
# preds: []
# true: []
# tp: 5 fp: 2 fn: 2
# preds: []
# true: []
# tp: 5 fp: 2 fn: 2
# preds: []
# true: []
# tp: 5 fp: 2 fn: 2
# preds: ['food']
# true: ['food']
# tp: 6 fp: 2 fn: 2
# preds: []
# true: []
# tp: 6 fp: 2 fn: 2
# preds: ['oil']
# true: ['oil']
# tp: 7 fp: 2 fn: 2
# preds: ['food']
# true: ['food']
# tp: 8 fp: 2 fn: 2
# preds: ['staff', 'food', 'place']
# true: ['staff', 'food', 'place']
# tp: 11 fp: 2 fn: 2
# preds: []
# true: []
# tp: 11 fp: 2 fn: 2
# preds: ['dinner']
# true: ['dinner']
# tp: 12 fp: 2 fn: 2
# preds: ['food']
# true: ['food']
# tp: 13 fp: 2 fn: 2
# preds: ['plate']
# true: ['plate']
# tp: 14 fp: 2 fn: 2
# preds: []
# true: []
# tp: 14 fp: 2 fn: 2
# preds: []
# true: []
# tp: 14 fp: 2 fn: 2
# preds: ['desserts']
# true: ['desserts']
# tp: 15 fp: 2 fn: 2
# preds: []
# true: []
# tp: 15 fp: 2 fn: 2
# preds: ['sushi bar', 'chef', 'carte']
# true: ['sushi bar', 'chef', 'ala carte']
# tp: 17 fp: 3 fn: 3
# preds: []
# true: ['spot']
# tp: 17 fp: 3 fn: 4
# preds: []
# true: []
# tp: 17 fp: 3 fn: 4
# preds: []
# true: []
# tp: 17 fp: 3 fn: 4
# preds: []
# true: []
# tp: 17 fp: 3 fn: 4
# preds: ['pizza', 'santa fe chopped salad', 'fish', 'chips']
# true: ['pizza', 'santa fe chopped salad', 'fish and chips']
# tp: 19 fp: 5 fn: 5
# preds: ['drinks']
# true: ['drinks']
# tp: 20 fp: 5 fn: 5
# preds: ['lava cake dessert']
# true: ['lava cake dessert']
# tp: 21 fp: 5 fn: 5
# preds: []
# true: []
# tp: 21 fp: 5 fn: 5
# preds: ['seafood dishes', 'appetizers']
# true: ['seafood dishes', 'appetizers']
# tp: 23 fp: 5 fn: 5
# preds: []
# true: []
# tp: 23 fp: 5 fn: 5
# preds: ['value']
# true: []
# tp: 23 fp: 6 fn: 5
# preds: ['calzones']
# true: ['calzones']
# tp: 24 fp: 6 fn: 5
# preds: ['waiters']
# true: ['waiters']
# tp: 25 fp: 6 fn: 5
# preds: []
# true: []
# tp: 25 fp: 6 fn: 5
# preds: ['glass of wine']
# true: ['glass of wine']
# tp: 26 fp: 6 fn: 5
# preds: ['pizza']
# true: ['pizza']
# tp: 27 fp: 6 fn: 5
# preds: ['drinks', 'wine selection', 'priced']
# true: ['drinks', 'wine selection', 'priced']
# tp: 30 fp: 6 fn: 5
# preds: ['bar food', 'menu', 'beers']
# true: ['bar food', 'menu', 'hand-crafted beers']
# tp: 32 fp: 7 fn: 6
# preds: ['food']
# true: ['food']
# tp: 33 fp: 7 fn: 6
# preds: []
# true: []
# tp: 33 fp: 7 fn: 6
# preds: ['Pizza']
# true: []
# tp: 33 fp: 8 fn: 6
# preds: ['sauce', 'crust']
# true: ['sauce', 'crust']
# tp: 35 fp: 8 fn: 6
# preds: []
# true: []
# tp: 35 fp: 8 fn: 6
# preds: ['reservation', 'table']
# true: ['reservation', 'table']
# tp: 37 fp: 8 fn: 6
# preds: ['food', 'atmosphere']
# true: ['food', 'atmosphere']
# tp: 39 fp: 8 fn: 6
# preds: ['food', 'dishes', 'drinks']
# true: ['food', 'dishes', 'drinks']
# tp: 42 fp: 8 fn: 6
# preds: ['interior decoration', 'chefs']
# true: ['interior decoration', 'chefs']
# tp: 44 fp: 8 fn: 6
# preds: ['Shabu-Shabu']
# true: []
# tp: 44 fp: 9 fn: 6
# preds: []
# true: []
# tp: 44 fp: 9 fn: 6
# preds: ['table']
# true: ['table']
# tp: 45 fp: 9 fn: 6
# preds: ['tiramisu chocolate cake']
# true: ['tiramisu chocolate cake']
# tp: 46 fp: 9 fn: 6
# preds: ['food', 'wait-staff', 'service', 'management']
# true: ['food', 'wait-staff', 'diner', 'service', 'management']
# tp: 50 fp: 9 fn: 7
# preds: ['dinner']
# true: ['casual dinner']
# tp: 50 fp: 10 fn: 8
# preds: []
# true: []
# tp: 50 fp: 10 fn: 8
# preds: []
# true: []
# tp: 50 fp: 10 fn: 8
# preds: ['wait']
# true: ['wait']
# tp: 51 fp: 10 fn: 8
# preds: ['Square cocktail', 'ginger lemonade', 'vodka', 'vodka']
# true: ['Times Square cocktail', 'ginger lemonade with vodka']
# tp: 51 fp: 13 fn: 10
# preds: ['food', 'service']
# true: ['food', 'service']
# tp: 53 fp: 13 fn: 10
# preds: []
# true: []
# tp: 53 fp: 13 fn: 10
# preds: ['food']
# true: ['food']
# tp: 54 fp: 13 fn: 10
# preds: ['ambience']
# true: ['ambience']
# tp: 55 fp: 13 fn: 10
# preds: []
# true: []
# tp: 55 fp: 13 fn: 10
# preds: []
# true: []
# tp: 55 fp: 13 fn: 10
# preds: ['Pad thai', 'lad nar', 'dishes', 'thai food']
# true: ['Pad thai', 'lad nar', 'dishes', 'thai food', 'places']
# tp: 59 fp: 13 fn: 11
# preds: ['workers', 'bagel', 'cream cheese']
# true: ['workers', 'bagel', 'cream cheese']
# tp: 62 fp: 13 fn: 11
# preds: ['service']
# true: ['service']
# tp: 63 fp: 13 fn: 11
# preds: ['service']
# true: ['service']
# tp: 64 fp: 13 fn: 11
# preds: []
# true: []
# tp: 64 fp: 13 fn: 11
# preds: ['prices', 'quality', 'service', 'food']
# true: ['prices', 'service', 'food']
# tp: 67 fp: 14 fn: 11
# preds: ['menu', 'potato pancakes']
# true: ['menu', 'potato pancakes']
# tp: 69 fp: 14 fn: 11
# preds: ['Frites']
# true: ['Frites']
# tp: 70 fp: 14 fn: 11
# preds: ['served', 'bannan fritter']
# true: ['served', 'bannan fritter']
# tp: 72 fp: 14 fn: 11
# preds: ['food', 'Indian cuisine']
# true: ['food', "'gourmet' Indian cuisine"]
# tp: 73 fp: 15 fn: 12
# preds: ['flavors']
# true: ['flavors']
# tp: 74 fp: 15 fn: 12
# preds: ['pad', 'dishes']
# true: ['pad see ew', 'dishes']
# tp: 75 fp: 16 fn: 13
# preds: ['delivery', 'Gnochi']
# true: ['Gnochi']
# tp: 76 fp: 17 fn: 13
# preds: []
# true: ['entertaining']
# tp: 76 fp: 17 fn: 14
# preds: ['atmosphere', 'dishes', 'service']
# true: ['atmosphere', 'dishes', 'service']
# tp: 79 fp: 17 fn: 14
# preds: ['pre-theater menu', 'roasted tomato soup with chevre', 'steak frites', 'creme brulee']
# true: ['pre-theater menu', 'roasted tomato soup with chevre', 'steak frites', 'creme brulee']
# tp: 83 fp: 17 fn: 14
# preds: []
# true: []
# tp: 83 fp: 17 fn: 14
# preds: ['plate', 'rice', 'entrees']
# true: ['rice', 'entrees']
# tp: 85 fp: 18 fn: 14
# preds: ['meal', 'tip', 'food']
# true: ['meal', 'tip', 'food']
# tp: 88 fp: 18 fn: 14
# preds: ['Spicy Scallop roll']
# true: ['Spicy Scallop roll']
# tp: 89 fp: 18 fn: 14
# preds: ['Service', 'ambience']
# true: ['Service', 'ambience']
# tp: 91 fp: 18 fn: 14
# preds: ['food', 'chicken vindaloo']
# true: ['spicy food', 'chicken vindaloo']
# tp: 92 fp: 19 fn: 15
# preds: ['owner', 'staff', 'ambiance']
# true: ['owner', 'staff', 'ambiance']
# tp: 95 fp: 19 fn: 15
# preds: ['menu choices', 'taste', 'flavor']
# true: ['menu choices', 'taste', 'flavor']
# tp: 98 fp: 19 fn: 15
# preds: []
# true: []
# tp: 98 fp: 19 fn: 15
# preds: ['cigar bar', 'staff']
# true: ['cigar bar', 'staff']
# tp: 100 fp: 19 fn: 15
# preds: []
# true: []
# tp: 100 fp: 19 fn: 15
# preds: ['lunch specials']
# true: ['lunch specials']
# tp: 101 fp: 19 fn: 15
# preds: ['SUPER HAPPY waiter']
# true: ['waiter']
# tp: 101 fp: 20 fn: 16
# preds: []
# true: []
# tp: 101 fp: 20 fn: 16
# preds: []
# true: []
# tp: 101 fp: 20 fn: 16
# preds: ['bagel']
# true: []
# tp: 101 fp: 21 fn: 16
# preds: ['chef']
# true: ['Sichuan chef']
# tp: 101 fp: 22 fn: 17
# preds: ['service', 'staff']
# true: ['service', 'staff']
# tp: 103 fp: 22 fn: 17
# preds: []
# true: []
# tp: 103 fp: 22 fn: 17
# preds: []
# true: []
# tp: 103 fp: 22 fn: 17
# preds: ['service']
# true: ['service']
# tp: 104 fp: 22 fn: 17
# preds: ['bagels', 'size']
# true: ['bagels']
# tp: 105 fp: 23 fn: 17
# preds: ['prices', 'ambience']
# true: ['prices', 'ambience']
# tp: 107 fp: 23 fn: 17
# preds: []
# true: []
# tp: 107 fp: 23 fn: 17
# preds: ['food', 'decor', 'service']
# true: ['food', 'decor', 'service']
# tp: 110 fp: 23 fn: 17
# preds: ['service', 'waitresses']
# true: ['service', 'waitresses']
# tp: 112 fp: 23 fn: 17
# preds: ['cheesecake']
# true: ['cheesecake']
# tp: 113 fp: 23 fn: 17
# preds: ['food']
# true: ['counter', 'food']
# tp: 114 fp: 23 fn: 18
# preds: ['mediterranean salad']
# true: ['mediterranean salad']
# tp: 115 fp: 23 fn: 18
# preds: ['course']
# true: ['course']
# tp: 116 fp: 23 fn: 18
# preds: ['dinner special']
# true: ['dinner special']
# tp: 117 fp: 23 fn: 18
# preds: ['Prices']
# true: ['Prices']
# tp: 118 fp: 23 fn: 18
# preds: ['food', 'House Roll', 'wait', 'Sake Bar']
# true: ['food', 'wait building']
# tp: 119 fp: 26 fn: 19
# preds: ['atmosphere', 'service', 'desert']
# true: ['atmosphere', 'service', 'desert']
# tp: 122 fp: 26 fn: 19
# preds: ['wait staff', 'aesthetic beautification']
# true: ['wait staff']
# tp: 123 fp: 27 fn: 19
# preds: ['bagels']
# true: ['bagels']
# tp: 124 fp: 27 fn: 19
# preds: ['quality', 'eats']
# true: ['quality']
# tp: 125 fp: 28 fn: 19
# preds: []
# true: []
# tp: 125 fp: 28 fn: 19
# preds: ['decore', 'food']
# true: ['decore', 'food']
# tp: 127 fp: 28 fn: 19
# preds: ['lunch']
# true: ['lunch']
# tp: 128 fp: 28 fn: 19
# preds: ['place', 'bar scene']
# true: ['place', 'bar scene']
# tp: 130 fp: 28 fn: 19
# preds: []
# true: ['check']
# tp: 130 fp: 28 fn: 20
# preds: ['Halibut', 'dessert', 'service']
# true: ['Halibut', 'dessert', 'service']
# tp: 133 fp: 28 fn: 20
# preds: []
# true: []
# tp: 133 fp: 28 fn: 20
# preds: []
# true: []
# tp: 133 fp: 28 fn: 20
# preds: ['glass of Leaping Lizard', 'glass of prosecco', 'mussels']
# true: ['glass of Leaping Lizard', 'glass of prosecco', 'mussels']
# tp: 136 fp: 28 fn: 20
# preds: ['menu prices', 'quality', 'portion size']
# true: ['menu prices', 'quality', 'portion size']
# tp: 139 fp: 28 fn: 20
# preds: []
# true: []
# tp: 139 fp: 28 fn: 20
# preds: ['Thai']
# true: ['Thai']
# tp: 140 fp: 28 fn: 20
# preds: ['service', 'server']
# true: ['service', 'server']
# tp: 142 fp: 28 fn: 20
# preds: []
# true: []
# tp: 142 fp: 28 fn: 20
# preds: ['value']
# true: []
# tp: 142 fp: 29 fn: 20
# preds: ['beer']
# true: ['beer']
# tp: 143 fp: 29 fn: 20
# preds: ['bread', 'pizza', 'pizza with prosciutto and baby arugula', 'margarite pizza', 'cold prosciutto', 'baby arugula', 'salad']
# true: ['bread', 'pizza', "Peter's Favourite pizza with prosciutto and baby arugula", 'margarite pizza with cold prosciutto and baby arugula on top', 'salad']
# tp: 146 fp: 33 fn: 22
# preds: []
# true: []
# tp: 146 fp: 33 fn: 22
# preds: ['roll', 'menu']
# true: ['roll', 'menu']
# tp: 148 fp: 33 fn: 22
# preds: ['food']
# true: ['food']
# tp: 149 fp: 33 fn: 22
# preds: ['caviar', 'waitstaff']
# true: ['caviar', 'waitstaff']
# tp: 151 fp: 33 fn: 22
# preds: ['green curry with vegetables']
# true: ['green curry with vegetables']
# tp: 152 fp: 33 fn: 22
# preds: ['dinner']
# true: ['dinner']
# tp: 153 fp: 33 fn: 22
# preds: ['meal', 'dishes']
# true: ['meal', 'cost', 'dishes']
# tp: 155 fp: 33 fn: 23
# preds: []
# true: []
# tp: 155 fp: 33 fn: 23
# preds: []
# true: []
# tp: 155 fp: 33 fn: 23
# preds: []
# true: []
# tp: 155 fp: 33 fn: 23
# preds: ['dim sum']
# true: ['dim sum']
# tp: 156 fp: 33 fn: 23
# preds: []
# true: []
# tp: 156 fp: 33 fn: 23
# preds: ['pastrami sandwich on', 'roll']
# true: ['pastrami sandwich']
# tp: 156 fp: 35 fn: 24
# preds: ['trays of Dim Sum']
# true: ['trays of Dim Sum']
# tp: 157 fp: 35 fn: 24
# preds: []
# true: []
# tp: 157 fp: 35 fn: 24
# preds: ['entrees']
# true: ['entrees']
# tp: 158 fp: 35 fn: 24
# preds: []
# true: ['money']
# tp: 158 fp: 35 fn: 25
# preds: ['Thai food', 'delivery']
# true: ['Thai food', 'delivery']
# tp: 160 fp: 35 fn: 25
# preds: ['Grilled Chicken special with Edamame Puree']
# true: ['Grilled Chicken special with Edamame Puree']
# tp: 161 fp: 35 fn: 25
# preds: ['food']
# true: ['food']
# tp: 162 fp: 35 fn: 25
# preds: []
# true: []
# tp: 162 fp: 35 fn: 25
# preds: []
# true: []
# tp: 162 fp: 35 fn: 25
# preds: []
# true: []
# tp: 162 fp: 35 fn: 25
# preds: ['sake list', 'Purple Haze']
# true: ['sake list', 'Purple Haze']
# tp: 164 fp: 35 fn: 25
# preds: ['dessert']
# true: ['dessert']
# tp: 165 fp: 35 fn: 25
# preds: ['food']
# true: ['food']
# tp: 166 fp: 35 fn: 25
# preds: ['menu']
# true: ['menu']
# tp: 167 fp: 35 fn: 25
# preds: ['Thai food']
# true: ['Thai food']
# tp: 168 fp: 35 fn: 25
# preds: ['Quality', 'Price']
# true: ['Quality', 'Price']
# tp: 170 fp: 35 fn: 25
# preds: ['slice', 'slice', 'mushroom', 'mushrooms']
# true: []
# tp: 170 fp: 38 fn: 25
# preds: ['service']
# true: ['service']
# tp: 171 fp: 38 fn: 25
# preds: ['waitress', 'food']
# true: ['waitress', 'food']
# tp: 173 fp: 38 fn: 25
# preds: []
# true: []
# tp: 173 fp: 38 fn: 25
# preds: ['service']
# true: ['service']
# tp: 174 fp: 38 fn: 25
# preds: ['seats']
# true: ['seats']
# tp: 175 fp: 38 fn: 25
# preds: ['food', 'garden']
# true: ['food', 'garden', 'place']
# tp: 177 fp: 38 fn: 26
# preds: ['salmon dish', 'price', 'flavor']
# true: ['salmon dish', 'price', 'flavor']
# tp: 180 fp: 38 fn: 26
# preds: ['three course meal', 'plate']
# true: ['three course meal']
# tp: 181 fp: 39 fn: 26
# preds: ['service', 'food', 'atmosphere', 'environment']
# true: ['service', 'food', 'atmosphere', 'environment']
# tp: 185 fp: 39 fn: 26
# preds: []
# true: []
# tp: 185 fp: 39 fn: 26
# preds: ['staff', 'bar']
# true: ['staff', 'bar']
# tp: 187 fp: 39 fn: 26
# preds: ['food', 'table']
# true: ['food', 'getting a table']
# tp: 188 fp: 40 fn: 27
# preds: []
# true: []
# tp: 188 fp: 40 fn: 27
# preds: ['sake']
# true: ['sake']
# tp: 189 fp: 40 fn: 27
# preds: ['prix fixe lunch', 'buffet']
# true: ['prix fixe lunch', 'buffet']
# tp: 191 fp: 40 fn: 27
# preds: ['served', 'interior']
# true: []
# tp: 191 fp: 42 fn: 27
# preds: ['menu']
# true: ['menu']
# tp: 192 fp: 42 fn: 27
# preds: ['wine']
# true: ['wine']
# tp: 193 fp: 42 fn: 27
# preds: []
# true: ['CUISINE']
# tp: 193 fp: 42 fn: 28
# preds: ['octopus eaters', 'Octopus salad']
# true: ['Octopus salad']
# tp: 194 fp: 43 fn: 28
# preds: ['thai']
# true: ['thai']
# tp: 195 fp: 43 fn: 28
# preds: []
# true: []
# tp: 195 fp: 43 fn: 28
# preds: ['spicy scallop roll', 'sesame chicken']
# true: ['scallop roll', 'sesame chicken']
# tp: 196 fp: 44 fn: 29
# preds: ['wine list', 'desserts']
# true: ['wine list', 'desserts']
# tp: 198 fp: 44 fn: 29
# preds: []
# true: []
# tp: 198 fp: 44 fn: 29
# preds: []
# true: ['upstairs']
# tp: 198 fp: 44 fn: 30
# preds: ['lox']
# true: ['lox']
# tp: 199 fp: 44 fn: 30
# preds: ['food']
# true: ['food']
# tp: 200 fp: 44 fn: 30
# preds: ['service', 'food']
# true: ['service', 'food']
# tp: 202 fp: 44 fn: 30
# preds: []
# true: []
# tp: 202 fp: 44 fn: 30
# preds: []
# true: []
# tp: 202 fp: 44 fn: 30
# preds: ['fish', 'rice']
# true: ['fish', 'rice']
# tp: 204 fp: 44 fn: 30
# preds: ['plates']
# true: ['plates']
# tp: 205 fp: 44 fn: 30
# preds: ['Thai food']
# true: ['Thai food']
# tp: 206 fp: 44 fn: 30
# preds: ['service', 'dinner', 'table']
# true: ['service', 'dinner', 'table']
# tp: 209 fp: 44 fn: 30
# preds: ['sushi', 'ceviche mix', 'crab dumplings', 'assorted sashimi', 'sushi', 'rolls', 'types of sake', 'banana tempura']
# true: ['sushi', 'ceviche mix (special)', 'crab dumplings', 'assorted sashimi', 'sushi', 'rolls', 'sake', 'banana tempura']
# tp: 214 fp: 46 fn: 32
# preds: ['drinks', 'service staff']
# true: ['drinks', 'service staff']
# tp: 216 fp: 46 fn: 32
# preds: ['waitstaff']
# true: ['waitstaff']
# tp: 217 fp: 46 fn: 32
# preds: []
# true: []
# tp: 217 fp: 46 fn: 32
# preds: ['cooking']
# true: ['cooking']
# tp: 218 fp: 46 fn: 32
# preds: []
# true: []
# tp: 218 fp: 46 fn: 32
# preds: []
# true: []
# tp: 218 fp: 46 fn: 32
# preds: ['Grilled whole fish']
# true: ['fish']
# tp: 218 fp: 47 fn: 33
# preds: ['server', 'food', 'drinks']
# true: ['server', 'served', 'food', 'drinks']
# tp: 221 fp: 47 fn: 34
# preds: []
# true: []
# tp: 221 fp: 47 fn: 34
# preds: ['service', 'ambience']
# true: ['service', 'ambience']
# tp: 223 fp: 47 fn: 34
# preds: ['reservations', 'hosting staff', 'reservation']
# true: ['reservations', 'hosting staff', 'seating', 'reservation']
# tp: 226 fp: 47 fn: 35
# 0.846441947565543 0.8278388278388278 0.8659003831417624 226 47 35
# preds: []
# true: ['crowds', 'lines']
# tp: 226 fp: 47 fn: 37
# preds: []
# true: []
# tp: 226 fp: 47 fn: 37
# preds: []
# true: []
# tp: 226 fp: 47 fn: 37
# preds: ['service']
# true: ['service']
# tp: 227 fp: 47 fn: 37
# preds: ['prices']
# true: ['prices']
# tp: 228 fp: 47 fn: 37
# preds: ['Pastrami sandwich', 'pickles', 'beer']
# true: ['Pastrami sandwich', 'pickles', 'beer']
# tp: 231 fp: 47 fn: 37
# preds: ['tip', 'food', 'service']
# true: ['tip', 'food', 'service']
# tp: 234 fp: 47 fn: 37
# preds: []
# true: []
# tp: 234 fp: 47 fn: 37
# preds: ['mushroom pizza']
# true: ['mushroom pizza']
# tp: 235 fp: 47 fn: 37
# preds: ['lollipop']
# true: []
# tp: 235 fp: 48 fn: 37
# preds: []
# true: []
# tp: 235 fp: 48 fn: 37
# preds: ['taste']
# true: ['taste']
# tp: 236 fp: 48 fn: 37
# preds: ['seltzer with lime', 'ice']
# true: ['seltzer with lime']
# tp: 237 fp: 49 fn: 37
# preds: []
# true: []
# tp: 237 fp: 49 fn: 37
# preds: ['wine list']
# true: ['wine list']
# tp: 238 fp: 49 fn: 37
# preds: []
# true: []
# tp: 238 fp: 49 fn: 37
# preds: ['atmosphere', 'Sushi']
# true: ['atmosphere']
# tp: 239 fp: 50 fn: 37
# preds: ['glass of wine']
# true: ['glass of wine']
# tp: 240 fp: 50 fn: 37
# preds: ['Caviar Russe', 'caviar', 'service']
# true: ['caviar', 'service']
# tp: 242 fp: 51 fn: 37
# preds: []
# true: ['traffic noise']
# tp: 242 fp: 51 fn: 38
# preds: []
# true: []
# tp: 242 fp: 51 fn: 38
# preds: ['service']
# true: ['service']
# tp: 243 fp: 51 fn: 38
# preds: []
# true: []
# tp: 243 fp: 51 fn: 38
# preds: []
# true: []
# tp: 243 fp: 51 fn: 38
# preds: []
# true: []
# tp: 243 fp: 51 fn: 38
# preds: ['noise level']
# true: ['noise level']
# tp: 244 fp: 51 fn: 38
# preds: []
# true: []
# tp: 244 fp: 51 fn: 38
# preds: []
# true: []
# tp: 244 fp: 51 fn: 38
# preds: ['Gnocchi']
# true: ['Gnocchi']
# tp: 245 fp: 51 fn: 38
# preds: []
# true: []
# tp: 245 fp: 51 fn: 38
# preds: ['food', 'manager', 'containers', 'condiments', 'containers']
# true: ['food', 'manager', 'employees', 'containers for condiments', 'containers']
# tp: 248 fp: 52 fn: 40
# preds: []
# true: []
# tp: 248 fp: 52 fn: 40
# preds: []
# true: []
# tp: 248 fp: 52 fn: 40
# preds: []
# true: ['cost']
# tp: 248 fp: 52 fn: 41
# preds: ['check', 'drinks']
# true: ['check', 'drinks']
# tp: 250 fp: 52 fn: 41
# preds: ['sushi bar']
# true: ['sushi bar']
# tp: 251 fp: 52 fn: 41
# preds: []
# true: []
# tp: 251 fp: 52 fn: 41
# preds: ['coat check girls', 'coat check girls']
# true: ['coat check girls', 'coat check girls']
# tp: 252 fp: 52 fn: 41
# preds: ['service']
# true: ['service']
# tp: 253 fp: 52 fn: 41
# preds: ['food']
# true: ['food']
# tp: 254 fp: 52 fn: 41
# preds: ['dinner']
# true: ['dinner']
# tp: 255 fp: 52 fn: 41
# preds: []
# true: []
# tp: 255 fp: 52 fn: 41
# preds: ['food', 'bombay style chaat', 'bhelpuri', 'sevpuri', 'samosa chaats', 'indian appetizers']
# true: ['food', 'bombay style chaat', 'bhelpuri', 'sevpuri', 'samosa chaats', 'indian appetizers']
# tp: 261 fp: 52 fn: 41
# preds: []
# true: []
# tp: 261 fp: 52 fn: 41
# preds: []
# true: []
# tp: 261 fp: 52 fn: 41
# preds: ['ambience']
# true: ['ambience']
# tp: 262 fp: 52 fn: 41
# preds: ['walls', 'food']
# true: ['walls', 'food']
# tp: 264 fp: 52 fn: 41
# preds: ['cole slaw', 'knish']
# true: ['cole slaw', 'knish']
# tp: 266 fp: 52 fn: 41
# preds: []
# true: []
# tp: 266 fp: 52 fn: 41
# preds: []
# true: []
# tp: 266 fp: 52 fn: 41
# preds: ['menu', 'entrees']
# true: ['menu', 'entrees']
# tp: 268 fp: 52 fn: 41
# preds: []
# true: []
# tp: 268 fp: 52 fn: 41
# preds: ['meal']
# true: ['meal']
# tp: 269 fp: 52 fn: 41
# preds: []
# true: ['Veal Parmigana']
# tp: 269 fp: 52 fn: 42
# preds: []
# true: []
# tp: 269 fp: 52 fn: 42
# preds: ['pizza']
# true: ['pizza']
# tp: 270 fp: 52 fn: 42
# preds: ['lunch', 'dinner', 'pre-theatre', 'after-theatre drinks']
# true: ['spot', 'lunch', 'dinner', 'pre-theatre or after-theatre drinks']
# tp: 272 fp: 54 fn: 44
# preds: ['food', 'portions']
# true: ['food', 'portions']
# tp: 274 fp: 54 fn: 44
# preds: ['Service', 'food']
# true: ['Service', 'food']
# tp: 276 fp: 54 fn: 44
# preds: ['sandwiches', 'chips', 'side']
# true: ['sandwiches', 'chips', 'side']
# tp: 279 fp: 54 fn: 44
# preds: []
# true: []
# tp: 279 fp: 54 fn: 44
# preds: ['specials']
# true: ['specials']
# tp: 280 fp: 54 fn: 44
# preds: ['susans', 'tables']
# true: ['lazy susans', 'tables']
# tp: 281 fp: 55 fn: 45
# preds: []
# true: ['place']
# tp: 281 fp: 55 fn: 46
# preds: ['space', 'tiled counters', 'bottles', 'cans', 'counter', 'entrees']
# true: ['corridor', 'space', 'counters', 'counter', 'entrees']
# tp: 284 fp: 58 fn: 48
# preds: ['menu', 'waiter', 'specials', 'main dishes']
# true: ['menu', 'waiter', 'specials', 'main dishes']
# tp: 288 fp: 58 fn: 48
# preds: []
# true: []
# tp: 288 fp: 58 fn: 48
# preds: []
# true: []
# tp: 288 fp: 58 fn: 48
# preds: ['waiters', 'owners']
# true: ['waiters', 'owners']
# tp: 290 fp: 58 fn: 48
# preds: ['menu']
# true: ['menu']
# tp: 291 fp: 58 fn: 48
# preds: ['bagels']
# true: ['bagels']
# tp: 292 fp: 58 fn: 48
# preds: []
# true: []
# tp: 292 fp: 58 fn: 48
# preds: []
# true: []
# tp: 292 fp: 58 fn: 48
# preds: ['service']
# true: ['service']
# tp: 293 fp: 58 fn: 48
# preds: ['Tuscan cuisine', 'Neapolitan fare']
# true: ['Tuscan cuisine', 'Neapolitan fare']
# tp: 295 fp: 58 fn: 48
# preds: []
# true: ['place', 'place']
# tp: 295 fp: 58 fn: 49
# preds: ['terrace', 'water', 'price']
# true: ['price']
# tp: 296 fp: 60 fn: 49
# preds: ['Service', 'takeout']
# true: ['Service', 'takeout']
# tp: 298 fp: 60 fn: 49
# preds: []
# true: ['Half-Price Saturday Night Special']
# tp: 298 fp: 60 fn: 50
# preds: ['dish']
# true: ['dish']
# tp: 299 fp: 60 fn: 50
# preds: ['ambiance']
# true: ['ambiance']
# tp: 300 fp: 60 fn: 50
# preds: []
# true: []
# tp: 300 fp: 60 fn: 50
# preds: ['Tasting']
# true: []
# tp: 300 fp: 61 fn: 50
# preds: []
# true: []
# tp: 300 fp: 61 fn: 50
# preds: ['servers']
# true: ['servers']
# tp: 301 fp: 61 fn: 50
# preds: []
# true: []
# tp: 301 fp: 61 fn: 50
# preds: ['environment', 'food', 'service']
# true: ['environment', 'food', 'service']
# tp: 304 fp: 61 fn: 50
# preds: []
# true: ['table']
# tp: 304 fp: 61 fn: 51
# preds: ['food', 'quality', 'food', 'priced']
# true: ['food', 'quality of food', 'priced']
# tp: 306 fp: 62 fn: 52
# preds: []
# true: []
# tp: 306 fp: 62 fn: 52
# preds: ['french indian', 'dishes']
# true: ['french indian fusion', 'dishes']
# tp: 307 fp: 63 fn: 53
# preds: ['dinner']
# true: ['Christmas dinner']
# tp: 307 fp: 64 fn: 54
# preds: ['lunch']
# true: ['lunch']
# tp: 308 fp: 64 fn: 54
# preds: ['toaster']
# true: ['toaster']
# tp: 309 fp: 64 fn: 54
# preds: ['indian cuisine']
# true: ['indian cuisine']
# tp: 310 fp: 64 fn: 54
# preds: ['crabmeat lasagna', 'chocolate bread pudding', 'dessert']
# true: ['crabmeat lasagna', 'chocolate bread pudding', 'dessert']
# tp: 313 fp: 64 fn: 54
# preds: ['food']
# true: ['food']
# tp: 314 fp: 64 fn: 54
# preds: ['meal']
# true: ['meal']
# tp: 315 fp: 64 fn: 54
# preds: []
# true: []
# tp: 315 fp: 64 fn: 54
# preds: ['scene']
# true: ['scene', 'customers']
# tp: 316 fp: 64 fn: 55
# preds: ['food']
# true: ['food']
# tp: 317 fp: 64 fn: 55
# preds: []
# true: ['line']
# tp: 317 fp: 64 fn: 56
# preds: ['prix fixe meal']
# true: ['prix fixe meal']
# tp: 318 fp: 64 fn: 56
# preds: ['flavors', 'menu']
# true: ['flavors', 'menu']
# tp: 320 fp: 64 fn: 56
# preds: ['menu', 'specials', 'quality', 'food']
# true: ['specials', 'quality', 'care', 'food']
# tp: 323 fp: 65 fn: 57
# preds: ['pizza', 'Neapolitan pizzaria']
# true: ['pizza']
# tp: 324 fp: 66 fn: 57
# preds: ['sushi', 'sushi bar']
# true: ['sushi', 'sushi bar']
# tp: 326 fp: 66 fn: 57
# preds: ['atmosphere']
# true: ['atmosphere', 'bagel']
# tp: 327 fp: 66 fn: 58
# preds: ['Service', 'food']
# true: ['Service', 'food']
# tp: 329 fp: 66 fn: 58
# preds: []
# true: []
# tp: 329 fp: 66 fn: 58
# preds: ['cuisine']
# true: ['cuisine']
# tp: 330 fp: 66 fn: 58
# preds: []
# true: []
# tp: 330 fp: 66 fn: 58
# preds: ['Sea Urchin', 'chef', 'fish', 'Fatty Yellow Tail', 'Boton Shrimp', 'Blue Fin Torro(Fatty Tuna)', 'Sea Eel']
# true: ['Sea Urchin', 'chef', 'assortment of fish', 'Fatty Yellow Tail', 'Boton Shrimp', 'Blue Fin Torro (Fatty Tuna)', 'Sea Eel']
# tp: 335 fp: 68 fn: 60
# preds: ['3', 'brunch', 'unlimited mimosas']
# true: ['brunch', 'mimosas']
# tp: 336 fp: 70 fn: 61
# preds: []
# true: []
# tp: 336 fp: 70 fn: 61
# preds: ['music']
# true: ['music']
# tp: 337 fp: 70 fn: 61
# preds: []
# true: []
# tp: 337 fp: 70 fn: 61
# preds: ['price', 'lunch special', 'dish']
# true: ['price', 'lunch special', 'dish']
# tp: 340 fp: 70 fn: 61
# preds: []
# true: []
# tp: 340 fp: 70 fn: 61
# preds: []
# true: []
# tp: 340 fp: 70 fn: 61
# preds: ['staff']
# true: ['staff']
# tp: 341 fp: 70 fn: 61
# preds: ['food quality', 'service']
# true: ['food quality', 'service']
# tp: 343 fp: 70 fn: 61
# preds: []
# true: []
# tp: 343 fp: 70 fn: 61
# preds: ['tip']
# true: ['tip']
# tp: 344 fp: 70 fn: 61
# preds: ['bill']
# true: ['bill']
# tp: 345 fp: 70 fn: 61
# preds: ['priced']
# true: ['priced']
# tp: 346 fp: 70 fn: 61
# preds: ['ambience']
# true: ['ambience']
# tp: 347 fp: 70 fn: 61
# preds: []
# true: []
# tp: 347 fp: 70 fn: 61
# preds: ['shrimp scampi', 'antipasti']
# true: ['shrimp scampi', 'antipasti']
# tp: 349 fp: 70 fn: 61
# preds: ['space', 'drink']
# true: ['space', 'drink']
# tp: 351 fp: 70 fn: 61
# preds: []
# true: []
# tp: 351 fp: 70 fn: 61
# preds: ['bun']
# true: ['bun']
# tp: 352 fp: 70 fn: 61
# preds: ['back garden sitting area', 'herb garden']
# true: ['back garden sitting area', 'personal herb garden']
# tp: 353 fp: 71 fn: 62
# preds: ['service', 'server', 'table']
# true: ['service', 'server', 'table']
# tp: 356 fp: 71 fn: 62
# preds: []
# true: []
# tp: 356 fp: 71 fn: 62
# preds: ['ambiance', 'atmosphere', 'food', 'service']
# true: ['ambiance', 'atmosphere', 'food', 'service']
# tp: 360 fp: 71 fn: 62
# preds: []
# true: []
# tp: 360 fp: 71 fn: 62
# preds: ['Edamame']
# true: ['Edamame pureed']
# tp: 360 fp: 72 fn: 63
# preds: ['food', 'service']
# true: ['food', 'service']
# tp: 362 fp: 72 fn: 63
# preds: ['answering machine', 'reservation']
# true: ['reservation']
# tp: 363 fp: 73 fn: 63
# preds: ['waiters', 'bill']
# true: ['waiters', 'bill']
# tp: 365 fp: 73 fn: 63
# preds: []
# true: []
# tp: 365 fp: 73 fn: 63
# preds: []
# true: []
# tp: 365 fp: 73 fn: 63
# preds: ['Sushi', 'price']
# true: ['Sushi', 'price']
# tp: 367 fp: 73 fn: 63
# preds: ['food']
# true: ['food']
# tp: 368 fp: 73 fn: 63
# preds: ['wait', 'table', 'table']
# true: ['wait', 'table', 'insde table']
# tp: 370 fp: 73 fn: 64
# preds: ['food']
# true: ['food']
# tp: 371 fp: 73 fn: 64
# preds: ['tables', 'menu', 'wine list']
# true: ['tables', 'menu', 'wine list']
# tp: 374 fp: 73 fn: 64
# preds: ['staff', 'chef']
# true: ['staff', 'chef']
# tp: 376 fp: 73 fn: 64
# preds: ['food', 'service']
# true: ['food', 'service']
# tp: 378 fp: 73 fn: 64
# preds: ['food', 'quality']
# true: ['food', 'quality']
# tp: 380 fp: 73 fn: 64
# preds: ['chutneys']
# true: ['chutneys']
# tp: 381 fp: 73 fn: 64
# preds: ['Service']
# true: ['Service']
# tp: 382 fp: 73 fn: 64
# preds: []
# true: []
# tp: 382 fp: 73 fn: 64
# preds: ['employees']
# true: ['employees']
# tp: 383 fp: 73 fn: 64
# preds: ['prices']
# true: ['prices']
# tp: 384 fp: 73 fn: 64
# preds: ['servers', 'servers']
# true: ['servers', 'servers']
# tp: 385 fp: 73 fn: 64
# preds: ['chicken dish', 'manager', 'dish']
# true: ['chicken dish', 'manager', 'dish']
# tp: 388 fp: 73 fn: 64
# preds: ['salad']
# true: ['salad', 'fast food']
# tp: 389 fp: 73 fn: 65
# preds: []
# true: []
# tp: 389 fp: 73 fn: 65
# preds: []
# true: []
# tp: 389 fp: 73 fn: 65
# preds: ['drumsticks', 'rice', 'spicy soup']
# true: ['drumsticks over rice', 'sour spicy soup']
# tp: 389 fp: 76 fn: 67
# preds: ['atmosphere']
# true: ['atmosphere']
# tp: 390 fp: 76 fn: 67
# preds: ['drinks', 'decor', 'food', 'people']
# true: ['drinks', 'decor', 'food']
# tp: 393 fp: 77 fn: 67
# preds: []
# true: []
# tp: 393 fp: 77 fn: 67
# preds: []
# true: []
# tp: 393 fp: 77 fn: 67
# preds: ['decor']
# true: ['decor']
# tp: 394 fp: 77 fn: 67
# preds: ['Sophia pizza']
# true: []
# tp: 394 fp: 78 fn: 67
# preds: []
# true: []
# tp: 394 fp: 78 fn: 67
# preds: ['takeout menu', 'menu', 'dishes']
# true: ['takeout menu', 'menu', 'italian dishes']
# tp: 396 fp: 79 fn: 68
# preds: []
# true: []
# tp: 396 fp: 79 fn: 68
# preds: ['service', 'atmosphere']
# true: ['service', 'atmosphere']
# tp: 398 fp: 79 fn: 68
# preds: ['food']
# true: ['food']
# tp: 399 fp: 79 fn: 68
# preds: ['dining']
# true: ['dining']
# tp: 400 fp: 79 fn: 68
# preds: []
# true: []
# tp: 400 fp: 79 fn: 68
# preds: []
# true: []
# tp: 400 fp: 79 fn: 68
# preds: ['fresh mozzerella slices', 'Plain Cheese slice']
# true: ['fresh mozzerella slices', 'Plain Cheese slice']
# tp: 402 fp: 79 fn: 68
# preds: ['pudding dessert']
# true: ['pudding dessert']
# tp: 403 fp: 79 fn: 68
# preds: ['reservations']
# true: ['reservations']
# tp: 404 fp: 79 fn: 68
# preds: []
# true: []
# tp: 404 fp: 79 fn: 68
# preds: ['price']
# true: ['price']
# tp: 405 fp: 79 fn: 68
# preds: ['food', 'staff']
# true: ['food', 'staff']
# tp: 407 fp: 79 fn: 68
# preds: ['vegetable samosa', 'malai tikka wrap']
# true: ['vegetable samosa', 'malai tikka wrap']
# tp: 409 fp: 79 fn: 68
# preds: []
# true: []
# tp: 409 fp: 79 fn: 68
# preds: []
# true: []
# tp: 409 fp: 79 fn: 68
# preds: ['chili']
# true: []
# tp: 409 fp: 80 fn: 68
# preds: []
# true: []
# tp: 409 fp: 80 fn: 68
# preds: []
# true: []
# tp: 409 fp: 80 fn: 68
# preds: []
# true: []
# tp: 409 fp: 80 fn: 68
# preds: []
# true: []
# tp: 409 fp: 80 fn: 68
# preds: ['chef', 'waitress']
# true: ['chef', 'waitress']
# tp: 411 fp: 80 fn: 68
# preds: []
# true: []
# tp: 411 fp: 80 fn: 68
# preds: ['food', 'service']
# true: ['food', 'service']
# tp: 413 fp: 80 fn: 68
# preds: ['plain pizza', 'wild mushroom(', 'Fornini)pizza', 'truffle oil']
# true: ['plain pizza', 'wild mushroom(third generation-Fornini) pizza', 'truffle oil']
# tp: 415 fp: 82 fn: 69
# preds: []
# true: []
# tp: 415 fp: 82 fn: 69
# preds: ['eggplant']
# true: ['eggplant']
# tp: 416 fp: 82 fn: 69
# preds: ['staff', 'service']
# true: ['staff', 'service']
# tp: 418 fp: 82 fn: 69
# preds: ['soup', 'udon', 'soy sauce', 'water']
# true: ['soup for the udon', 'soy sauce', 'water']
# tp: 420 fp: 84 fn: 70
# preds: ['cod with paella', 'fish and chips', 'serving', 'pieces', 'fish', 'basketful of fries']
# true: ['cod with paella', 'fish and chips', 'serving', 'fish', 'fries']
# tp: 424 fp: 86 fn: 71
# preds: ['service']
# true: ['service']
# tp: 425 fp: 86 fn: 71
# preds: ['meal']
# true: ['meal']
# tp: 426 fp: 86 fn: 71
# preds: ['Thai noodles with shrimp', 'chicken', 'coconut juice']
# true: ['Thai noodles with shrimp and chicken and coconut juice']
# tp: 426 fp: 89 fn: 72
# preds: ['sashimi', 'portions']
# true: ['sashimi', 'portions']
# tp: 428 fp: 89 fn: 72
# preds: ['service']
# true: ['service']
# tp: 429 fp: 89 fn: 72
# preds: []
# true: ['TOASTING']
# tp: 429 fp: 89 fn: 73
# preds: ['food']
# true: ['food']
# tp: 430 fp: 89 fn: 73
# preds: ['staff']
# true: ['staff']
# tp: 431 fp: 89 fn: 73
# preds: ['Pad Se-Ew', 'Chicken with Cashew Nuts']
# true: ['Pad Se-Ew', 'Chicken with Cashew Nuts']
# tp: 433 fp: 89 fn: 73
# preds: ['service']
# true: ['service']
# tp: 434 fp: 89 fn: 73
# preds: ['chu chu curry', 'pad thai chicken']
# true: ['chu chu curry', 'pad thai chicken']
# tp: 436 fp: 89 fn: 73
# preds: ['Seating']
# true: ['Seating']
# tp: 437 fp: 89 fn: 73
# preds: ['table']
# true: ['table']
# tp: 438 fp: 89 fn: 73
# preds: ['decor']
# true: ['decor']
# tp: 439 fp: 89 fn: 73
# preds: ['ambience', 'lunch']
# true: ['ambience', 'lunch']
# tp: 441 fp: 89 fn: 73
# preds: []
# true: []
# tp: 441 fp: 89 fn: 73
# preds: ['food']
# true: ['food']
# tp: 442 fp: 89 fn: 73
# preds: ['food']
# true: ['food spot']
# tp: 442 fp: 90 fn: 74
# 0.8435114503816793 0.8308270676691729 0.8565891472868217 442 90 74
# preds: ['shabu']
# true: []
# tp: 442 fp: 91 fn: 74
# preds: ['food', 'striped bass']
# true: ['food', 'striped bass']
# tp: 444 fp: 91 fn: 74
# preds: ['white bean brushetta', 'pasta']
# true: ['white bean brushetta', 'pasta']
# tp: 446 fp: 91 fn: 74
# preds: ['pasta dishes', 'tiramisu']
# true: ['pasta dishes', 'tiramisu']
# tp: 448 fp: 91 fn: 74
# preds: []
# true: []
# tp: 448 fp: 91 fn: 74
# preds: ['Thai food', 'service']
# true: ['Thai food', 'service']
# tp: 450 fp: 91 fn: 74
# preds: []
# true: []
# tp: 450 fp: 91 fn: 74
# preds: ['wine selection', 'glass', 'bottle', 'reservation']
# true: ['wine selection', 'reservation']
# tp: 452 fp: 93 fn: 74
# preds: []
# true: []
# tp: 452 fp: 93 fn: 74
# preds: ['pie']
# true: []
# tp: 452 fp: 94 fn: 74
# preds: ['food', 'price', 'fried dumplings']
# true: ['food', 'price', 'fried dumplings']
# tp: 455 fp: 94 fn: 74
# preds: ['sandwhiches']
# true: ['sandwhiches']
# tp: 456 fp: 94 fn: 74
# preds: ['barebecued salmon']
# true: ['barebecued salmon']
# tp: 457 fp: 94 fn: 74
# preds: ['bacon', 'sandwiches', 'frying']
# true: ['bacon', 'platter', 'in sandwiches', 'frying', 'bacos']
# tp: 459 fp: 95 fn: 77
# preds: ['prices', 'food']
# true: ['prices', 'food']
# tp: 461 fp: 95 fn: 77
# preds: ['crust', 'take-out pies']
# true: ['crust', 'take-out pies']
# tp: 463 fp: 95 fn: 77
# preds: ['food']
# true: ['food']
# tp: 464 fp: 95 fn: 77
# preds: ['back patio', 'music']
# true: ['back patio', 'music']
# tp: 466 fp: 95 fn: 77
# preds: ['service', 'food']
# true: ['service', 'food']
# tp: 468 fp: 95 fn: 77
# preds: ['management']
# true: ['management']
# tp: 469 fp: 95 fn: 77
# preds: []
# true: []
# tp: 469 fp: 95 fn: 77
# preds: ['wine list']
# true: ['wine list']
# tp: 470 fp: 95 fn: 77
# preds: ['food']
# true: ['food']
# tp: 471 fp: 95 fn: 77
# preds: ['atmosphere']
# true: ['atmosphere']
# tp: 472 fp: 95 fn: 77
# preds: ['seafood', 'wine list', 'menu']
# true: ['seafood', 'wine list', 'menu']
# tp: 475 fp: 95 fn: 77
# preds: ['appetizers']
# true: ['appetizers']
# tp: 476 fp: 95 fn: 77
# preds: ['drinks', 'desserts']
# true: ['place', 'drinks', 'desserts']
# tp: 478 fp: 95 fn: 78
# preds: ['wait', 'noise']
# true: ['rush', 'wait', 'noise']
# tp: 480 fp: 95 fn: 79
# preds: []
# true: []
# tp: 480 fp: 95 fn: 79
# preds: []
# true: []
# tp: 480 fp: 95 fn: 79
# preds: []
# true: []
# tp: 480 fp: 95 fn: 79
# preds: ['pad penang']
# true: ['pad penang']
# tp: 481 fp: 95 fn: 79
# preds: ['place']
# true: ['place']
# tp: 482 fp: 95 fn: 79
# preds: ['staff', 'meal']
# true: ['staff', 'meal']
# tp: 484 fp: 95 fn: 79
# preds: []
# true: []
# tp: 484 fp: 95 fn: 79
# preds: ['food', 'priced']
# true: ['food', 'priced']
# tp: 486 fp: 95 fn: 79
# preds: ['table', 'reservations']
# true: ['table', 'reservations']
# tp: 488 fp: 95 fn: 79
# preds: ['Prices']
# true: ['Prices']
# tp: 489 fp: 95 fn: 79
# preds: []
# true: ['spot']
# tp: 489 fp: 95 fn: 80
# preds: []
# true: []
# tp: 489 fp: 95 fn: 80
# preds: ['thai food']
# true: ['thai food']
# tp: 490 fp: 95 fn: 80
# preds: []
# true: []
# tp: 490 fp: 95 fn: 80
# preds: ['waiter']
# true: ['waiter']
# tp: 491 fp: 95 fn: 80
# preds: []
# true: ['cater']
# tp: 491 fp: 95 fn: 81
# preds: ['service', 'food', 'managers']
# true: ['service', 'food', 'managers']
# tp: 494 fp: 95 fn: 81
# preds: []
# true: []
# tp: 494 fp: 95 fn: 81
# preds: ['Italian food']
# true: ['Italian food']
# tp: 495 fp: 95 fn: 81
# preds: ['eats', 'drinks', 'setting']
# true: ['eats', 'drinks', 'setting']
# tp: 498 fp: 95 fn: 81
# preds: []
# true: []
# tp: 498 fp: 95 fn: 81
# preds: ['Go Go Hamburgers']
# true: ['Go Go Hamburgers']
# tp: 499 fp: 95 fn: 81
# preds: ['people']
# true: ['people']
# tp: 500 fp: 95 fn: 81
# preds: []
# true: []
# tp: 500 fp: 95 fn: 81
# preds: ['lox', 'mussels', 'cod', 'trout', 'dinner']
# true: ['lox', 'mussels', 'cod', 'trout', 'dinner']
# tp: 505 fp: 95 fn: 81
# preds: ['Sake bar']
# true: ['bar']
# tp: 505 fp: 96 fn: 82
# preds: ['pad thai']
# true: ['pad thai']
# tp: 506 fp: 96 fn: 82
# preds: ['waitress']
# true: ['waitress']
# tp: 507 fp: 96 fn: 82
# preds: ['Italian food']
# true: ['Italian food']
# tp: 508 fp: 96 fn: 82
# preds: []
# true: []
# tp: 508 fp: 96 fn: 82
# preds: ['seafood', 'vegetables', 'portion']
# true: ['seafood', 'vegetables', 'portion size']
# tp: 510 fp: 97 fn: 83
# preds: []
# true: []
# tp: 510 fp: 97 fn: 83
# preds: ['banana tower', 'dessert']
# true: ['banana tower', 'dessert']
# tp: 512 fp: 97 fn: 83
# preds: ['Thai food']
# true: ['Thai food']
# tp: 513 fp: 97 fn: 83
# preds: []
# true: []
# tp: 513 fp: 97 fn: 83
# preds: []
# true: []
# tp: 513 fp: 97 fn: 83
# preds: ['bagels', 'priced']
# true: ['bagels', 'priced']
# tp: 515 fp: 97 fn: 83
# preds: ['menu', 'dumplings', 'appetizer section']
# true: ['menu', 'dumplings', 'appetizer']
# tp: 517 fp: 98 fn: 84
# preds: ['appetizers', 'salads', 'steak', 'pasta']
# true: ['appetizers', 'salads', 'steak', 'pasta']
# tp: 521 fp: 98 fn: 84
# preds: ['wine list', 'staff', 'owners', 'menu']
# true: ['wine list', 'staff', 'owners', 'menu']
# tp: 525 fp: 98 fn: 84
# preds: []
# true: []
# tp: 525 fp: 98 fn: 84
# preds: []
# true: []
# tp: 525 fp: 98 fn: 84
# preds: []
# true: []
# tp: 525 fp: 98 fn: 84
# preds: []
# true: []
# tp: 525 fp: 98 fn: 84
# preds: []
# true: ['place']
# tp: 525 fp: 98 fn: 85
# preds: ['Fast Food']
# true: []
# tp: 525 fp: 99 fn: 85
# preds: ['pasta']
# true: ['pasta']
# tp: 526 fp: 99 fn: 85
# preds: []
# true: []
# tp: 526 fp: 99 fn: 85
# preds: ['sushi', 'thai food']
# true: ['sushi', 'thai food']
# tp: 528 fp: 99 fn: 85
# preds: []
# true: []
# tp: 528 fp: 99 fn: 85
# preds: ['food']
# true: ['food', 'amount']
# tp: 529 fp: 99 fn: 86
# preds: ['sushi', 'Kamikaze', 'Rolls']
# true: ['sushi', 'Kamikaze', 'Rolls']
# tp: 532 fp: 99 fn: 86
# preds: []
# true: []
# tp: 532 fp: 99 fn: 86
# preds: ['ambience']
# true: ['ambience', 'place']
# tp: 533 fp: 99 fn: 87
# preds: []
# true: []
# tp: 533 fp: 99 fn: 87
# preds: []
# true: []
# tp: 533 fp: 99 fn: 87
# preds: ['lunch']
# true: ['lunch']
# tp: 534 fp: 99 fn: 87
# preds: ['food', 'busboy', 'waiter', 'cheese', 'pasta', 'water', 'wine glasses', 'meal', 'wine']
# true: ['food', 'busboy', 'waiter', 'cheese', 'pasta', 'water and wine glasses', 'meal', 'wine']
# tp: 541 fp: 101 fn: 88
# preds: []
# true: []
# tp: 541 fp: 101 fn: 88
# preds: ['beer selection']
# true: ['beer selection']
# tp: 542 fp: 101 fn: 88
# preds: ['drink', 'hong-kong styled milk and tea with tapioca pearls']
# true: ['drink', 'hong-kong styled milk', 'tea with tapioca pearls (hot)']
# tp: 543 fp: 102 fn: 90
# preds: ['lunch', 'dinner']
# true: ['dine', 'lunch', 'dinner']
# tp: 545 fp: 102 fn: 91
# preds: ['service', 'crab-cake eggs benedict']
# true: ['service', 'crab-cake eggs benedict']
# tp: 547 fp: 102 fn: 91
# preds: ['service']
# true: ['service']
# tp: 548 fp: 102 fn: 91
# preds: ['bartender', 'champagne', 'bottle', 'turnip soup with pureed basil']
# true: ['bartender', 'champagne', 'turnip soup with pureed basil']
# tp: 551 fp: 103 fn: 91
# preds: ['food']
# true: ['food']
# tp: 552 fp: 103 fn: 91
# preds: []
# true: []
# tp: 552 fp: 103 fn: 91
# preds: ['food', 'service', 'ambience']
# true: ['food', 'service', 'ambience']
# tp: 555 fp: 103 fn: 91
# preds: ['check', 'glass of water']
# true: ['check', 'table', 'glass of water']
# tp: 557 fp: 103 fn: 92
# preds: ['owner']
# true: ['owner']
# tp: 558 fp: 103 fn: 92
# preds: ['food']
# true: ['food']
# tp: 559 fp: 103 fn: 92
# preds: ['restuarant', 'tables']
# true: ['round tables', 'Taiwanese']
# tp: 559 fp: 105 fn: 94
# preds: []
# true: []
# tp: 559 fp: 105 fn: 94
# preds: ['Service', 'decor']
# true: ['Service', 'decor']
# tp: 561 fp: 105 fn: 94
# preds: []
# true: []
# tp: 561 fp: 105 fn: 94
# preds: ['Staff']
# true: ['Staff']
# tp: 562 fp: 105 fn: 94
# preds: ['yellowfun tuna', 'mussel selection']
# true: ['yellowfun tuna', 'mussel selection']
# tp: 564 fp: 105 fn: 94
# preds: []
# true: []
# tp: 564 fp: 105 fn: 94
# preds: []
# true: ['eating']
# tp: 564 fp: 105 fn: 95
# preds: []
# true: []
# tp: 564 fp: 105 fn: 95
# preds: ['bluetooth']
# true: ['adding the bluetooth']
# tp: 564 fp: 106 fn: 96
# preds: ['Windows 7 Starter']
# true: ['Windows 7 Starter']
# tp: 565 fp: 106 fn: 96
# preds: ['powerpoint', 'mac']
# true: ['powerpoint']
# tp: 566 fp: 107 fn: 96
# preds: ['screen']
# true: ['screen']
# tp: 567 fp: 107 fn: 96
# preds: ['tech support']
# true: ['tech support']
# tp: 568 fp: 107 fn: 96
# preds: []
# true: []
# tp: 568 fp: 107 fn: 96
# preds: []
# true: []
# tp: 568 fp: 107 fn: 96
# preds: ['sound']
# true: ['sound']
# tp: 569 fp: 107 fn: 96
# preds: ['charges']
# true: ['charges']
# tp: 570 fp: 107 fn: 96
# preds: []
# true: []
# tp: 570 fp: 107 fn: 96
# preds: []
# true: []
# tp: 570 fp: 107 fn: 96
# preds: ['hardware drivers']
# true: ['standard os cd', 'proprietary hardware drivers']
# tp: 570 fp: 108 fn: 98
# preds: ['software']
# true: ['proprietary software']
# tp: 570 fp: 109 fn: 99
# preds: ['touch pad', 'clicker']
# true: ['combined touch pad and clicker']
# tp: 570 fp: 111 fn: 100
# preds: []
# true: []
# tp: 570 fp: 111 fn: 100
# preds: []
# true: ['Looks', 'feel']
# tp: 570 fp: 111 fn: 102
# preds: []
# true: ['video']
# tp: 570 fp: 111 fn: 103
# preds: ['17 inch screen']
# true: ['17 inch screen']
# tp: 571 fp: 111 fn: 103
# preds: ['quality', 'price']
# true: ['quality', 'price']
# tp: 573 fp: 111 fn: 103
# preds: ['unibody design']
# true: ['unibody design']
# tp: 574 fp: 111 fn: 103
# preds: []
# true: []
# tp: 574 fp: 111 fn: 103
# preds: []
# true: []
# tp: 574 fp: 111 fn: 103
# preds: ['portability']
# true: ['portability']
# tp: 575 fp: 111 fn: 103
# preds: []
# true: []
# tp: 575 fp: 111 fn: 103
# preds: []
# true: []
# tp: 575 fp: 111 fn: 103
# preds: []
# true: []
# tp: 575 fp: 111 fn: 103
# preds: ['touch pad']
# true: ['touch pad']
# tp: 576 fp: 111 fn: 103
# preds: []
# true: []
# tp: 576 fp: 111 fn: 103
# preds: ['salesman', 'software']
# true: ['software']
# tp: 577 fp: 112 fn: 103
# preds: []
# true: []
# tp: 577 fp: 112 fn: 103
# preds: []
# true: []
# tp: 577 fp: 112 fn: 103
# preds: ['Office', 'features', 'functioning', 'pre installed mac programs']
# true: ['Office', 'features', 'functioning', 'programs']
# tp: 580 fp: 113 fn: 104
# preds: ['software']
# true: ['software']
# tp: 581 fp: 113 fn: 104
# preds: []
# true: ['internet', 'managing personal files']
# tp: 581 fp: 113 fn: 106
# preds: ['battery life', 'web browsing', 'gaming', 'playing', 'battery life']
# true: ['battery life', 'web browsing', 'word editing', 'gaming', 'movie playing', 'battery life']
# tp: 584 fp: 114 fn: 108
# preds: []
# true: []
# tp: 584 fp: 114 fn: 108
# preds: ['worked']
# true: ['company']
# tp: 584 fp: 115 fn: 109
# preds: []
# true: []
# tp: 584 fp: 115 fn: 109
# preds: ['size']
# true: ['size']
# tp: 585 fp: 115 fn: 109
# preds: []
# true: []
# tp: 585 fp: 115 fn: 109
# preds: ['power', 'flexibility']
# true: ['power', 'flexibility']
# tp: 587 fp: 115 fn: 109
# preds: []
# true: []
# tp: 587 fp: 115 fn: 109
# preds: []
# true: ['15 inch']
# tp: 587 fp: 115 fn: 110
# preds: ['Vista']
# true: ['Vista']
# tp: 588 fp: 115 fn: 110
# preds: []
# true: []
# tp: 588 fp: 115 fn: 110
# preds: ['use']
# true: ['use']
# tp: 589 fp: 115 fn: 110
# preds: ['Price', 'purpose']
# true: ['Price']
# tp: 590 fp: 116 fn: 110
# preds: ['delivery']
# true: ['delivery']
# tp: 591 fp: 116 fn: 110
# preds: []
# true: []
# tp: 591 fp: 116 fn: 110
# preds: []
# true: []
# tp: 591 fp: 116 fn: 110
# preds: ['Windows 7']
# true: ['wireless system', 'Windows 7']
# tp: 592 fp: 116 fn: 111
# preds: []
# true: []
# tp: 592 fp: 116 fn: 111
# preds: ['antivirus software', 'firewall']
# true: ['antivirus software', 'firewall']
# tp: 594 fp: 116 fn: 111
# preds: []
# true: []
# tp: 594 fp: 116 fn: 111
# preds: []
# true: []
# tp: 594 fp: 116 fn: 111
# preds: ['fit', 'feel']
# true: ['13 inch']
# tp: 594 fp: 118 fn: 112
# preds: []
# true: []
# tp: 594 fp: 118 fn: 112
# preds: ['warranty']
# true: ['warranty']
# tp: 595 fp: 118 fn: 112
# preds: ['Browsing', 'itunes']
# true: ['Browsing', 'itunes']
# tp: 597 fp: 118 fn: 112
# preds: ['touchpad']
# true: ['touchpad', 'buttons']
# tp: 598 fp: 118 fn: 113
# preds: []
# true: []
# tp: 598 fp: 118 fn: 113
# preds: ['Delivery']
# true: ['Delivery']
# tp: 599 fp: 118 fn: 113
# preds: ['programs', 'use', 'works']
# true: ['programs', 'use']
# tp: 601 fp: 119 fn: 113
# preds: []
# true: []
# tp: 601 fp: 119 fn: 113
# preds: ['transporting']
# true: ['transporting']
# tp: 602 fp: 119 fn: 113
# preds: ['battery life']
# true: ['battery life']
# tp: 603 fp: 119 fn: 113
# preds: ['Applications', 'MS applications']
# true: ['Applications', 'MS applications']
# tp: 605 fp: 119 fn: 113
# preds: []
# true: []
# tp: 605 fp: 119 fn: 113
# preds: []
# true: []
# tp: 605 fp: 119 fn: 113
# preds: []
# true: []
# tp: 605 fp: 119 fn: 113
# preds: ['apple care']
# true: ['apple care']
# tp: 606 fp: 119 fn: 113
# preds: ['warranty']
# true: ['warranty']
# tp: 607 fp: 119 fn: 113
# preds: []
# true: []
# tp: 607 fp: 119 fn: 113
# preds: ['power horse']
# true: []
# tp: 607 fp: 120 fn: 113
# preds: ['audio']
# true: ['audio']
# tp: 608 fp: 120 fn: 113
# preds: []
# true: []
# tp: 608 fp: 120 fn: 113
# preds: []
# true: []
# tp: 608 fp: 120 fn: 113
# preds: ['browsing']
# true: ['every day computing', 'web browsing']
# tp: 608 fp: 121 fn: 115
# preds: ['Iphoto']
# true: ['Iphoto']
# tp: 609 fp: 121 fn: 115
# preds: ['build', 'battery life']
# true: ['build', 'wt', 'battery life']
# tp: 611 fp: 121 fn: 116
# preds: []
# true: []
# tp: 611 fp: 121 fn: 116
# preds: []
# true: []
# tp: 611 fp: 121 fn: 116
# preds: []
# true: []
# tp: 611 fp: 121 fn: 116
# preds: ['price']
# true: ['price']
# tp: 612 fp: 121 fn: 116
# preds: []
# true: []
# tp: 612 fp: 121 fn: 116
# preds: []
# true: []
# tp: 612 fp: 121 fn: 116
# preds: []
# true: []
# tp: 612 fp: 121 fn: 116
# preds: ['Windows']
# true: ['Windows']
# tp: 613 fp: 121 fn: 116
# preds: ['ITouch 8Gig']
# true: []
# tp: 613 fp: 122 fn: 116
# preds: []
# true: ['technical person']
# tp: 613 fp: 122 fn: 117
# preds: ['memory', '17-inch screen', 'DVD', 'CD burners']
# true: ['memory', '17-inch screen', 'DVD', 'CD burners']
# tp: 617 fp: 122 fn: 117
# preds: []
# true: []
# tp: 617 fp: 122 fn: 117
# preds: []
# true: []
# tp: 617 fp: 122 fn: 117
# preds: ['features']
# true: ['features']
# tp: 618 fp: 122 fn: 117
# preds: ['processor', 'memory', 'hard drive', 'web cam', 'screen', 'features']
# true: ['processor', 'memory', 'hard drive', 'web cam', 'screen', 'features']
# tp: 624 fp: 122 fn: 117
# preds: []
# true: []
# tp: 624 fp: 122 fn: 117
# preds: []
# true: []
# tp: 624 fp: 122 fn: 117
# preds: []
# true: ['cost']
# tp: 624 fp: 122 fn: 118
# preds: []
# true: []
# tp: 624 fp: 122 fn: 118
# preds: []
# true: []
# tp: 624 fp: 122 fn: 118
# preds: ['Mac computer programs', 'navigation', 'functions']
# true: ['programs', 'navigation']
# tp: 625 fp: 124 fn: 119
# preds: ['OS', 'processor speed', 'thunderbolt port']
# true: ['OS', 'processor speed', 'thunderbolt port']
# tp: 628 fp: 124 fn: 119
# preds: []
# true: []
# tp: 628 fp: 124 fn: 119
# preds: ['programs', 'Keynote', 'Pages']
# true: ['programs', 'Keynote', 'Pages', 'Numbers']
# tp: 631 fp: 124 fn: 120
# preds: []
# true: []
# tp: 631 fp: 124 fn: 120
# preds: []
# true: []
# tp: 631 fp: 124 fn: 120
# preds: []
# true: []
# tp: 631 fp: 124 fn: 120
# preds: []
# true: ['patches']
# tp: 631 fp: 124 fn: 121
# preds: ['software', 'software']
# true: ['software', 'software']
# tp: 632 fp: 124 fn: 121
# 0.8376408217362492 0.8359788359788359 0.8393094289508632 632 124 121
# preds: ['calculator', 'keyboard']
# true: ['keyboard']
# tp: 633 fp: 125 fn: 121
# preds: ['keyboard']
# true: ['keyboard']
# tp: 634 fp: 125 fn: 121
# preds: []
# true: []
# tp: 634 fp: 125 fn: 121
# preds: ['keyboard', 'keys', 'key']
# true: ['keyboard', 'keys', 'configuration of "extra key"']
# tp: 636 fp: 126 fn: 122
# preds: []
# true: []
# tp: 636 fp: 126 fn: 122
# preds: ['bars', 'bar']
# true: []
# tp: 636 fp: 128 fn: 122
# preds: ['Aspire', 'screen', 'Droid', 'USB port']
# true: ['boot', 'Acer screen', 'USB port']
# tp: 637 fp: 131 fn: 124
# preds: ['screen resolutions']
# true: ['screen resolutions']
# tp: 638 fp: 131 fn: 124
# preds: ['Product support']
# true: ['Product support']
# tp: 639 fp: 131 fn: 124
# preds: []
# true: []
# tp: 639 fp: 131 fn: 124
# preds: ['UPS shipping']
# true: ['shipping']
# tp: 639 fp: 132 fn: 125
# preds: []
# true: []
# tp: 639 fp: 132 fn: 125
# preds: []
# true: []
# tp: 639 fp: 132 fn: 125
# preds: []
# true: []
# tp: 639 fp: 132 fn: 125
# preds: ['Garageband', 'microphone']
# true: ['Garageband', 'microphone']
# tp: 641 fp: 132 fn: 125
# preds: []
# true: []
# tp: 641 fp: 132 fn: 125
# preds: []
# true: []
# tp: 641 fp: 132 fn: 125
# preds: []
# true: []
# tp: 641 fp: 132 fn: 125
# preds: ['DVD burner', '80-gigabyte HD', 'graphics chip', 'components']
# true: ['DVD burner', 'HD', 'graphics chip', 'components']
# tp: 644 fp: 133 fn: 126
# preds: []
# true: []
# tp: 644 fp: 133 fn: 126
# preds: ['hard drive', 'mother board']
# true: ['hard drive', 'mother board']
# tp: 646 fp: 133 fn: 126
# preds: []
# true: []
# tp: 646 fp: 133 fn: 126
# preds: ['size', 'screen']
# true: ['size of the screen', 'tote']
# tp: 646 fp: 135 fn: 128
# preds: ['lock-up', 'Appleworks', 'browser']
# true: ['Appleworks', 'browser']
# tp: 648 fp: 136 fn: 128
# preds: []
# true: []
# tp: 648 fp: 136 fn: 128
# preds: ['plastic']
# true: ['manuf']
# tp: 648 fp: 137 fn: 129
# preds: ['running', 'memory']
# true: ['memory']
# tp: 649 fp: 138 fn: 129
# preds: ['Webcam']
# true: ['Webcam']
# tp: 650 fp: 138 fn: 129
# preds: []
# true: []
# tp: 650 fp: 138 fn: 129
# preds: []
# true: []
# tp: 650 fp: 138 fn: 129
# preds: []
# true: []
# tp: 650 fp: 138 fn: 129
# preds: []
# true: []
# tp: 650 fp: 138 fn: 129
# preds: []
# true: []
# tp: 650 fp: 138 fn: 129
# preds: []
# true: []
# tp: 650 fp: 138 fn: 129
# preds: []
# true: []
# tp: 650 fp: 138 fn: 129
# preds: []
# true: []
# tp: 650 fp: 138 fn: 129
# preds: ['power supply']
# true: ['power supply']
# tp: 651 fp: 138 fn: 129
# preds: []
# true: []
# tp: 651 fp: 138 fn: 129
# preds: []
# true: []
# tp: 651 fp: 138 fn: 129
# preds: ['Fan vents', 'cooling pad', 'feature']
# true: ['Fan', 'cooling pad', 'feature']
# tp: 653 fp: 139 fn: 130
# preds: []
# true: []
# tp: 653 fp: 139 fn: 130
# preds: ['hardware']
# true: ['hardware']
# tp: 654 fp: 139 fn: 130
# preds: []
# true: []
# tp: 654 fp: 139 fn: 130
# preds: ['works', 'use', 'Microsoft Office apps']
# true: ['internet use', 'Microsoft Office apps']
# tp: 655 fp: 141 fn: 131
# preds: []
# true: []
# tp: 655 fp: 141 fn: 131
# preds: ['Keyboard', 'sized']
# true: ['Keyboard', 'use']
# tp: 656 fp: 142 fn: 132
# preds: ['applications', 'Microsoft office']
# true: ['applications', 'Microsoft office']
# tp: 658 fp: 142 fn: 132
# preds: ['RMA service', 'PrePaid UPS shipping']
# true: ['RMA service']
# tp: 659 fp: 143 fn: 132
# preds: ['Toshiba Net book operates']
# true: ['operates']
# tp: 659 fp: 144 fn: 133
# preds: []
# true: []
# tp: 659 fp: 144 fn: 133
# preds: ['McAffe', 'Symantec']
# true: []
# tp: 659 fp: 146 fn: 133
# preds: []
# true: []
# tp: 659 fp: 146 fn: 133
# preds: ['RAM']
# true: ['RAM']
# tp: 660 fp: 146 fn: 133
# preds: []
# true: []
# tp: 660 fp: 146 fn: 133
# preds: ['processor', 'Apple OSX 16', 'graphics', 'hardware', 'software']
# true: ['processor', 'OSX 16', 'graphics', 'hardware', 'software']
# tp: 664 fp: 147 fn: 134
# preds: ['graphics', 'screen']
# true: ['graphics', 'screen']
# tp: 666 fp: 147 fn: 134
# preds: ['wait']
# true: []
# tp: 666 fp: 148 fn: 134
# preds: []
# true: []
# tp: 666 fp: 148 fn: 134
# ...
# true: []
# tp: 736 fp: 174 fn: 167
# preds: ['case design']
# true: ['case design']
# tp: 737 fp: 174 fn: 167
# preds: ['bill']
# true: []
# tp: 737 fp: 175 fn: 167
# preds: ['programs']
# true: ['programs']
# tp: 738 fp: 175 fn: 167
# preds: []
# true: []
# tp: 738 fp: 175 fn: 167
# preds: []
# true: []
# tp: 738 fp: 175 fn: 167
# preds: []
# true: []
# tp: 738 fp: 175 fn: 167
# preds: []
# true: []
# tp: 738 fp: 175 fn: 167
# preds: ['built in camera']
# true: ['built in camera']
# tp: 739 fp: 175 fn: 167
# preds: []
# true: []
# tp: 739 fp: 175 fn: 167
# preds: []
# true: []
# tp: 739 fp: 175 fn: 167
# preds: ['mousepad sensitivity']
# true: ['mousepad sensitivity']
# tp: 740 fp: 175 fn: 167
# preds: []
# true: []
# tp: 740 fp: 175 fn: 167
# preds: ['screen size', 'browsing']
# true: ['screen size', 'web browsing']
# tp: 741 fp: 176 fn: 168
# preds: []
# true: []
# tp: 741 fp: 176 fn: 168
# preds: ['tutorials']
# true: ['tutorials']
# tp: 742 fp: 176 fn: 168
# preds: ['boots up']
# true: ['boots up']
# tp: 743 fp: 176 fn: 168
# preds: []
# true: []
# tp: 743 fp: 176 fn: 168
# preds: []
# true: []
# tp: 743 fp: 176 fn: 168
# preds: []
# true: []
# tp: 743 fp: 176 fn: 168
# preds: ['touch pad']
# true: ['touch pad']
# tp: 744 fp: 176 fn: 168
# preds: ['memory', 'hard drive']
# true: ['memory', 'hard drive']
# tp: 746 fp: 176 fn: 168
# preds: []
# true: []
# tp: 746 fp: 176 fn: 168
# preds: ['resolution', 'screen']
# true: ['resolution of the screen']
# tp: 746 fp: 178 fn: 169
# preds: []
# true: []
# tp: 746 fp: 178 fn: 169
# preds: []
# true: []
# tp: 746 fp: 178 fn: 169
# preds: []
# true: []
# tp: 746 fp: 178 fn: 169
# preds: ['use']
# true: ['use']
# tp: 747 fp: 178 fn: 169
# preds: ['monitor']
# true: ['monitor']
# tp: 748 fp: 178 fn: 169
# preds: ['goes']
# true: []
# tp: 748 fp: 179 fn: 169
# preds: []
# true: []
# tp: 748 fp: 179 fn: 169
# preds: ['windows vista system']
# true: ['windows vista system']
# tp: 749 fp: 179 fn: 169
# preds: []
# true: []
# tp: 749 fp: 179 fn: 169
# preds: ['4', '1 GB ram SATA']
# true: ['Pentium 4', '1 GB ram']
# tp: 749 fp: 181 fn: 171
# preds: []
# true: []
# tp: 749 fp: 181 fn: 171
# preds: []
# true: []
# tp: 749 fp: 181 fn: 171
# 0.8097297297297297 0.8053763440860215 0.8141304347826087 749 181 171
# preds: []
# true: []
# tp: 749 fp: 181 fn: 171
# preds: []
# true: []
# tp: 749 fp: 181 fn: 171
# preds: ['screen']
# true: ['screen']
# tp: 750 fp: 181 fn: 171
# preds: []
# true: []
# tp: 750 fp: 181 fn: 171
# preds: ['quality']
# true: ['quality']
# tp: 751 fp: 181 fn: 171
# preds: ['Garmin GPS software', 'Microsoft Office 2003']
# true: ['Garmin GPS software', 'Microsoft Office 2003']
# tp: 753 fp: 181 fn: 171
# preds: ['batteries']
# true: ['batteries']
# tp: 754 fp: 181 fn: 171
# preds: []
# true: []
# tp: 754 fp: 181 fn: 171
# preds: ['Battery']
# true: ['Battery', 'surfing the web']
# tp: 755 fp: 181 fn: 172
# preds: []
# true: []
# tp: 755 fp: 181 fn: 172
# preds: ['staff', 'fan']
# true: ['staff', 'fan noise']
# tp: 756 fp: 182 fn: 173
# preds: ['iMovie']
# true: ['iMovie']
# tp: 757 fp: 182 fn: 173
# preds: ['keyboard']
# true: ['backlit keyboard']
# tp: 757 fp: 183 fn: 174
# preds: ['System', 'performance']
# true: ['System', 'performance']
# tp: 759 fp: 183 fn: 174
# preds: []
# true: []
# tp: 759 fp: 183 fn: 174
# preds: ['aluminum body']
# true: ['aluminum body']
# tp: 760 fp: 183 fn: 174
# preds: ['programs', 'drivers', 'powering']
# true: ['programs', 'drivers']
# tp: 762 fp: 184 fn: 174
# preds: []
# true: []
# tp: 762 fp: 184 fn: 174
# preds: ['hard drive', 'battery']
# true: ['hard drive', 'battery']
# tp: 764 fp: 184 fn: 174
# preds: ['speakers']
# true: ['speakers']
# tp: 765 fp: 184 fn: 174
# preds: []
# true: []
# tp: 765 fp: 184 fn: 174
# preds: ['RAM', 'memory']
# true: ['RAM', 'memory']
# tp: 767 fp: 184 fn: 174
# preds: []
# true: []
# tp: 767 fp: 184 fn: 174
# preds: []
# true: []
# tp: 767 fp: 184 fn: 174
# preds: []
# true: []
# tp: 767 fp: 184 fn: 174
# preds: []
# true: []
# tp: 767 fp: 184 fn: 174
# preds: ['mouse', 'flat panel', 'bar']
# true: ['mouse']
# tp: 768 fp: 186 fn: 174
# preds: []
# true: []
# tp: 768 fp: 186 fn: 174
# preds: []
# true: []
# tp: 768 fp: 186 fn: 174
# preds: []
# true: []
# tp: 768 fp: 186 fn: 174
# preds: []
# true: []
# tp: 768 fp: 186 fn: 174
# preds: ['iLife', 'Microsoft Office']
# true: ['iLife', 'Microsoft Office']
# tp: 770 fp: 186 fn: 174
# preds: ['loads', 'programs']
# true: ['loads', 'programs']
# tp: 772 fp: 186 fn: 174
# preds: []
# true: []
# tp: 772 fp: 186 fn: 174
# preds: []
# true: []
# tp: 772 fp: 186 fn: 174
# preds: ['black keyboard']
# true: ['black keyboard']
# tp: 773 fp: 186 fn: 174
# preds: []
# true: []
# tp: 773 fp: 186 fn: 174
# preds: []
# true: []
# tp: 773 fp: 186 fn: 174
# preds: ['Windows XP SP2']
# true: ['Windows XP SP2']
# tp: 774 fp: 186 fn: 174
# preds: ['ergonomic', 'lightweight power supply', 'power supply']
# true: ['power supply', 'power supply']
# tp: 775 fp: 188 fn: 174
# preds: ['use']
# true: ['use']
# tp: 776 fp: 188 fn: 174
# preds: []
# true: []
# tp: 776 fp: 188 fn: 174
# preds: []
# true: []
# tp: 776 fp: 188 fn: 174
# preds: ['touchpad']
# true: ['touchpad']
# tp: 777 fp: 188 fn: 174
# preds: ['startup', 'shutdown times']
# true: []
# tp: 777 fp: 190 fn: 174
# preds: []
# true: []
# tp: 777 fp: 190 fn: 174
# preds: ['support line']
# true: ['support line']
# tp: 778 fp: 190 fn: 174
# preds: []
# true: []
# tp: 778 fp: 190 fn: 174
# preds: []
# true: []
# tp: 778 fp: 190 fn: 174
# preds: ['multi-touch trackpad']
# true: ['multi-touch trackpad']
# tp: 779 fp: 190 fn: 174
# preds: []
# true: []
# tp: 779 fp: 190 fn: 174
# preds: []
# true: []
# tp: 779 fp: 190 fn: 174
# preds: []
# true: []
# tp: 779 fp: 190 fn: 174
# preds: []
# true: []
# tp: 779 fp: 190 fn: 174
# preds: []
# true: []
# tp: 779 fp: 190 fn: 174
# preds: []
# true: []
# tp: 779 fp: 190 fn: 174
# preds: ['battery life', 'performance', 'memory']
# true: ['battery life', 'performance', 'memory']
# tp: 782 fp: 190 fn: 174
# preds: []
# true: []
# tp: 782 fp: 190 fn: 174
# preds: ['screen', 'display', 'browsers']
# true: ['screen', 'display', 'browsers']
# tp: 785 fp: 190 fn: 174
# preds: ['visual']
# true: ['visual']
# tp: 786 fp: 190 fn: 174
# preds: ['network']
# true: []
# tp: 786 fp: 191 fn: 174
# preds: ['windows']
# true: []
# tp: 786 fp: 192 fn: 174
# preds: []
# true: []
# tp: 786 fp: 192 fn: 174
# preds: []
# true: []
# tp: 786 fp: 192 fn: 174
# preds: ['hard disc']
# true: ['hard disc']
# tp: 787 fp: 192 fn: 174
# preds: []
# true: []
# tp: 787 fp: 192 fn: 174
# preds: ['operation system']
# true: ['operation system']
# tp: 788 fp: 192 fn: 174
# preds: []
# true: []
# tp: 788 fp: 192 fn: 174
# preds: []
# true: []
# tp: 788 fp: 192 fn: 174
# preds: []
# true: []
# tp: 788 fp: 192 fn: 174
# preds: []
# true: []
# tp: 788 fp: 192 fn: 174
# preds: []
# true: []
# tp: 788 fp: 192 fn: 174
# preds: []
# true: []
# tp: 788 fp: 192 fn: 174
# preds: []
# true: []
# tp: 788 fp: 192 fn: 174
# preds: []
# true: ['ASUS TECH SUPPORT']
# tp: 788 fp: 192 fn: 175
# preds: []
# true: []
# tp: 788 fp: 192 fn: 175
# preds: ['mouse button']
# true: ['mouse button']
# tp: 789 fp: 192 fn: 175
# preds: ['power supply']
# true: ['power supply']
# tp: 790 fp: 192 fn: 175
# preds: ['port']
# true: ['port']
# tp: 791 fp: 192 fn: 175
# preds: ['i3 processor', 'fan']
# true: ['i3 processor', 'fan']
# tp: 793 fp: 192 fn: 175
# preds: []
# true: []
# tp: 793 fp: 192 fn: 175
# preds: []
# true: []
# tp: 793 fp: 192 fn: 175
# preds: ['price', 'features']
# true: ['price', 'features']
# tp: 795 fp: 192 fn: 175
# preds: []
# true: []
# tp: 795 fp: 192 fn: 175
# preds: []
# true: []
# tp: 795 fp: 192 fn: 175
# preds: []
# true: []
# tp: 795 fp: 192 fn: 175
# preds: ['service']
# true: ['service']
# tp: 796 fp: 192 fn: 175
# preds: []
# true: []
# tp: 796 fp: 192 fn: 175
# preds: []
# true: []
# tp: 796 fp: 192 fn: 175
# preds: []
# true: []
# tp: 796 fp: 192 fn: 175
# preds: ['OS']
# true: ['OS']
# tp: 797 fp: 192 fn: 175
# preds: ['start menu']
# true: ['start menu', 'navigate']
# tp: 798 fp: 192 fn: 176
# preds: []
# true: []
# tp: 798 fp: 192 fn: 176
# preds: ['battery life']
# true: ['battery life']
# tp: 799 fp: 192 fn: 176
# preds: ['internet capabilities']
# true: ['internet capabilities']
# tp: 800 fp: 192 fn: 176
# preds: ['style', 'speed']
# true: ['style', 'speed']
# tp: 802 fp: 192 fn: 176
# preds: ['work']
# true: []
# tp: 802 fp: 193 fn: 176
# preds: ['battery']
# true: ['battery']
# tp: 803 fp: 193 fn: 176
# preds: []
# true: []
# tp: 803 fp: 193 fn: 176
# preds: []
# true: []
# tp: 803 fp: 193 fn: 176
# preds: []
# true: []
# tp: 803 fp: 193 fn: 176
# preds: ['functions']
# true: ['functions']
# tp: 804 fp: 193 fn: 176
# preds: []
# true: []
# tp: 804 fp: 193 fn: 176
# preds: ['quality']
# true: ['quality']
# tp: 805 fp: 193 fn: 176
# preds: ['grounding', 'ground loop isolator', 'quality', 'price']
# true: ['components', 'ground loop isolator', 'quality', 'price range']
# tp: 807 fp: 195 fn: 178
# preds: ['value', 'delivery', 'works']
# true: ['value', 'delivery']
# tp: 809 fp: 196 fn: 178
# preds: ['features']
# true: ['features']
# tp: 810 fp: 196 fn: 178
# preds: []
# true: []
# tp: 810 fp: 196 fn: 178
# preds: ['battery']
# true: ['battery']
# tp: 811 fp: 196 fn: 178
# preds: []
# true: []
# tp: 811 fp: 196 fn: 178
# preds: []
# true: ['work']
# tp: 811 fp: 196 fn: 179
# preds: []
# true: []
# tp: 811 fp: 196 fn: 179
# preds: []
# true: []
# tp: 811 fp: 196 fn: 179
# preds: ['use']
# true: ['use']
# tp: 812 fp: 196 fn: 179
# preds: ['programs', 'programs', 'functionally']
# true: ['programs', 'programs']
# tp: 813 fp: 197 fn: 179
# preds: ['sound']
# true: ['sound']
# tp: 814 fp: 197 fn: 179
# preds: ['Microsoft Student Edition']
# true: ['Microsoft Student Edition']
# tp: 815 fp: 197 fn: 179
# preds: ['external monitor']
# true: ['Size', 'external monitor']
# tp: 816 fp: 197 fn: 180
# preds: ['BOTH recovery DVDs', 'driver/application DVD']
# true: ['recovery DVDs', 'driver/application DVD']
# tp: 817 fp: 198 fn: 181
# preds: ['touch']
# true: []
# tp: 817 fp: 199 fn: 181
# preds: ['backlit keyboard']
# true: ['backlit keyboard']
# tp: 818 fp: 199 fn: 181
# preds: []
# true: []
# tp: 818 fp: 199 fn: 181
# preds: []
# true: []
# tp: 818 fp: 199 fn: 181
# preds: []
# true: []
# tp: 818 fp: 199 fn: 181
# preds: []
# true: []
# tp: 818 fp: 199 fn: 181
# preds: []
# true: []
# tp: 818 fp: 199 fn: 181
# preds: []
# true: []
# tp: 818 fp: 199 fn: 181
# preds: ['tech support', 'software', 'software', 'booting']
# true: ['software', 'software', 'booting']
# tp: 820 fp: 200 fn: 181
# preds: []
# true: []
# tp: 820 fp: 200 fn: 181
# preds: ['hard drive']
# true: ['hard drive']
# tp: 821 fp: 200 fn: 181
# preds: []
# true: []
# tp: 821 fp: 200 fn: 181
# preds: ['lasting battery']
# true: ['battery']
# tp: 821 fp: 201 fn: 182
# preds: ['monitor']
# true: ['monitor']
# tp: 822 fp: 201 fn: 182
# preds: []
# true: []
# tp: 822 fp: 201 fn: 182
# preds: ['runs']
# true: ['runs']
# tp: 823 fp: 201 fn: 182
# preds: ['mouse keys']
# true: ['mouse keys']
# tp: 824 fp: 201 fn: 182
# preds: ['2GB stick', 'system']
# true: ['system']
# tp: 825 fp: 202 fn: 182
# preds: ['battery']
# true: ['battery']
# tp: 826 fp: 202 fn: 182
# preds: []
# true: ['noise']
# tp: 826 fp: 202 fn: 183
# preds: []
# true: []
# tp: 826 fp: 202 fn: 183
# preds: []
# true: []
# tp: 826 fp: 202 fn: 183
# preds: []
# true: []
# tp: 826 fp: 202 fn: 183
# preds: ['speed']
# true: ['speed']
# tp: 827 fp: 202 fn: 183
# preds: []
# true: ['sound']
# tp: 827 fp: 202 fn: 184
# preds: []
# true: []
# tp: 827 fp: 202 fn: 184
# preds: []
# true: ['carry']
# tp: 827 fp: 202 fn: 185
# preds: []
# true: []
# tp: 827 fp: 202 fn: 185
# preds: ['programs', 'ILife', 'iPhotos']
# true: ['programs', 'ILife', 'iPhotos']
# tp: 830 fp: 202 fn: 185
# preds: ['battery life']
# true: ['battery life']
# tp: 831 fp: 202 fn: 185
# preds: []
# true: []
# tp: 831 fp: 202 fn: 185
# preds: ['graphics', 'programs', 'Garageband', 'default background']
# true: ['graphics', 'programs', 'Garageband', 'default background']
# tp: 835 fp: 202 fn: 185
# preds: ['price']
# true: ['price']
# tp: 836 fp: 202 fn: 185
# preds: ['camera', 'specifications']
# true: ['camera', 'specifications']
# tp: 838 fp: 202 fn: 185
# preds: []
# true: []
# tp: 838 fp: 202 fn: 185
# preds: ['battery life', 'battery']
# true: ['battery life', 'battery']
# tp: 840 fp: 202 fn: 185
# preds: ['graphics', 'wireless']
# true: ['graphics', 'wireless switch']
# tp: 841 fp: 203 fn: 186
# preds: ['features']
# true: ['features']
# tp: 842 fp: 203 fn: 186
# preds: ['quality', 'speakers']
# true: ['speakers']
# tp: 843 fp: 204 fn: 186
# preds: []
# true: []
# tp: 843 fp: 204 fn: 186
# preds: []
# true: []
# tp: 843 fp: 204 fn: 186
# preds: []
# true: []
# tp: 843 fp: 204 fn: 186
# preds: ['Screen', 'battery life']
# true: ['Screen', 'battery life']
# tp: 845 fp: 204 fn: 186
# preds: []
# true: []
# tp: 845 fp: 204 fn: 186
# preds: []
# true: []
# tp: 845 fp: 204 fn: 186
# preds: ['quality']
# true: ['quality']
# tp: 846 fp: 204 fn: 186
# preds: []
# true: []
# tp: 846 fp: 204 fn: 186
# preds: []
# true: []
# tp: 846 fp: 204 fn: 186
# preds: []
# true: ['programs']
# tp: 846 fp: 204 fn: 187
# preds: ['feature']
# true: ['feature']
# tp: 847 fp: 204 fn: 187
# preds: []
# true: []
# tp: 847 fp: 204 fn: 187
# preds: []
# true: []
# tp: 847 fp: 204 fn: 187
# preds: []
# true: []
# tp: 847 fp: 204 fn: 187
# preds: ['AC plug']
# true: ['AC plug']
# tp: 848 fp: 204 fn: 187
# preds: ['run', 'memory']
# true: ['run', 'memory']
# tp: 850 fp: 204 fn: 187
# preds: []
# true: []
# tp: 850 fp: 204 fn: 187
# preds: ['Apple display', 'design']
# true: ['design', 'tech issues']
# tp: 851 fp: 205 fn: 188
# preds: []
# true: []
# tp: 851 fp: 205 fn: 188
# preds: []
# true: []
# tp: 851 fp: 205 fn: 188
# preds: ['cooling system', 'grafics card', '5870', '8GB RAM', 'LED backlit screen']
# true: ['cooling system', 'grafics card', '8GB RAM', 'LED backlit screen']
# tp: 855 fp: 206 fn: 188
# preds: ['battery life']
# true: ['battery life']
# tp: 856 fp: 206 fn: 188
# preds: ['keys']
# true: ['keys']
# tp: 857 fp: 206 fn: 188
# preds: []
# true: []
# tp: 857 fp: 206 fn: 188
# preds: []
# true: []
# tp: 857 fp: 206 fn: 188
# preds: []
# true: []
# tp: 857 fp: 206 fn: 188
# preds: []
# true: []
# tp: 857 fp: 206 fn: 188
# preds: []
# true: []
# tp: 857 fp: 206 fn: 188
# preds: []
# true: []
# tp: 857 fp: 206 fn: 188
# preds: ['IWORKS', 'Itunes', 'Email', 'MS Office', 'network', 'printers']
# true: ['IWORKS', 'Itunes', 'MS Office']
# tp: 860 fp: 209 fn: 188
# preds: ['HDD', 'main hard drive']
# true: ['HDD', 'rails', 'hard drive']
# tp: 861 fp: 210 fn: 190
# preds: []
# true: []
# tp: 861 fp: 210 fn: 190
# preds: ['customer support', 'feature', 'performance']
# true: ['customer support', 'safety feature', 'performance']
# tp: 863 fp: 211 fn: 191
# preds: []
# true: []
# tp: 863 fp: 211 fn: 191
# preds: []
# true: []
# tp: 863 fp: 211 fn: 191
# preds: ['charge']
# true: ['charge']
# tp: 864 fp: 211 fn: 191
# preds: ['worked', 'BIOS']
# true: ['BIOS']
# tp: 865 fp: 212 fn: 191
# preds: []
# true: []
# tp: 865 fp: 212 fn: 191
# preds: []
# true: []
# tp: 865 fp: 212 fn: 191
# preds: ['programs', 'Keynote', 'Garageband', 'management', 'Photo Booth', 'iPhoto', 'iMovie']
# true: ['programs', 'school or office use', 'Pages', 'Numbers', 'Keynote', 'music', 'Garageband', 'photo management', 'Photo Booth', 'iPhoto', 'video-editing', 'movie-making', 'iMovie']
# tp: 871 fp: 213 fn: 198
# preds: []
# true: []
# tp: 871 fp: 213 fn: 198
# preds: ['screen', 'gaming']
# true: ['screen', 'gaming']
# tp: 873 fp: 213 fn: 198
# preds: []
# true: []
# tp: 873 fp: 213 fn: 198
# preds: ['Technical Support']
# true: ['HP Technical Support']
# tp: 873 fp: 214 fn: 199
# preds: []
# true: []
# tp: 873 fp: 214 fn: 199
# preds: []
# true: []
# tp: 873 fp: 214 fn: 199
# preds: []
# true: []
# tp: 873 fp: 214 fn: 199
# preds: []
# true: []
# tp: 873 fp: 214 fn: 199
# preds: []
# true: []
# tp: 873 fp: 214 fn: 199
# preds: ['applications']
# true: ['applications']
# tp: 874 fp: 214 fn: 199
# preds: ['hook up']
# true: ['hook up to other wireless networks']
# tp: 874 fp: 215 fn: 200
# preds: ['works']
# true: ['works']
# tp: 875 fp: 215 fn: 200
# preds: ['screen']
# true: ['screen']
# tp: 876 fp: 215 fn: 200
# preds: ['screen']
# true: ['screen']
# tp: 877 fp: 215 fn: 200
# preds: []
# true: []
# tp: 877 fp: 215 fn: 200
# preds: ['Geek Squad', 'Customer Service']
# true: ['Customer Service']
# tp: 878 fp: 216 fn: 200
# preds: []
# true: []
# tp: 878 fp: 216 fn: 200
# preds: ['runs']
# true: ['runs']
# tp: 879 fp: 216 fn: 200
# preds: []
# true: []
# tp: 879 fp: 216 fn: 200
# 0.8086476540938362 0.8027397260273973 0.8146431881371641 879 216 200
# preds: ['Bluetooth', 'fingerprint reader driver', 'software']
# true: ['Bluetooth', 'fingerprint reader driver', 'software']
# tp: 882 fp: 216 fn: 200
# 0.8091743119266054 0.8032786885245902 0.8151571164510166 882 216 200
#
# --------------------------------------------------------------------------------
# DATALOADER:0 TEST RESULTS
# {'test_f1': 0.8291758894920349,
#  'test_precision': 0.8205362558364868,
#  'test_recall': 0.8380933403968811}
# --------------------------------------------------------------------------------
# [{'test_f1': 0.8291758894920349,
#   'test_precision': 0.8205362558364868,
#   'test_recall': 0.8380933403968811}]

# %% [markdown]
# - F1: 0.8091743119266054
# - prec: 0.8032786885245902
# - rec: 0.8151571164510166

# %%
# !ls -la checkpoints/

# %%
# !mv checkpoints/best_model-v1.ckpt ./best_model_A-to_try.ckpt
# Out:
# mv: cannot stat 'checkpoints/best_model-v1.ckpt': No such file or directory

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard

# %%
# Let's see how training goes on tensorboard. This is optional as one can use the logbar of PL to track training. 
# %tensorboard --logdir lightning_logs/
